# %%
#import dependencies
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
from datetime import datetime

#import Socrata to pull API data...may need to run pip install sodapy
from sodapy import Socrata

#import password for mySQL from config.py.
from config import password

# import app_token (if desired) from app_token.py to prevent limited pull requests
# from app_token import app_token

# %%
#call Socrata without app_token
client = Socrata("data.cdc.gov", None)

# # Example authenticated client (needed for non-public datasets):
# client = Socrata("data.cdc.gov", app_token)

#requests result, limit is 25000 to ensure full data is pulled
results = client.get("a3uk-kgrx", limit="25000")

# Convert to pandas DataFrame
drug_df = pd.DataFrame.from_records(results)

#create month and year string from month and year columns
drug_df["month-year"] = drug_df["month"].apply(lambda x: x[:3]) + "-" + drug_df["year"]

#converty month-year column to datetime

# drug_df["month-year"] = pd.to_datetime(drug_df["month-year"])


#drop duplicate entries from dataframe
drug_df = drug_df.drop_duplicates(subset=['footnote', 'indicator', 'state', 'month-year', "data_value"])
drug_df = drug_df.reset_index(drop=True)
drug_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#              data_value                                           footnote  \
# 0                    24  Numbers may differ from published reports usin...
# 1                 89864  Numbers may differ from published reports usin...
# 2                   271  Numbers may differ from published reports usin...
# 3                   236  Numbers may differ from published reports usin...
# 4       85.557639810282  Numbers may differ from published reports usin...
# 5                 69856  Numbers may differ from published reports usin...
# 6                    79  Numbers may differ from published reports usin...
# 7                     6  Numbers may differ from published reports usin...
# 8                 10237  Numbers may differ from published reports usin...
# 9                   292  Numbers may differ from published reports usin...
# 10                   41  Numbers may differ from published reports usin...
# 11                   32              Underreported due to incomplete data.
# 12                 8740  Numbers may differ from published reports usin...
# 13                 1162  Numbers may differ from published reports usin...
# 14     98.1481481481482  Numbers may differ from published reports usin...
# 15                60964  Numbers may differ from published reports usin...
# 16                82813  Numbers may differ from published reports usin...
# 17                   29              Underreported due to incomplete data.
# 18                   39  Numbers may differ from published reports usin...
# 19                   51  Numbers may differ from published reports usin...
# 20                13897  Numbers may differ from published reports usin...
# 21                 1101  Numbers may differ from published reports usin...
# 22                   50  Numbers may differ from published reports usin...
# 23                   60  Numbers may differ from published reports usin...
# 24                  355  Numbers may differ from published reports usin...
# 25                  166  Numbers may differ from published reports usin...
# 26                  294  Numbers may differ from published reports usin...
# 27     98.1762917933131  Numbers may differ from published reports usin...
# 28                 8216  Numbers may differ from published reports usin...
# 29                30641  Numbers may differ from published reports usin...
# ...                 ...                                                ...
# 13806               107  Numbers may differ from published reports usin...
# 13807               667              Underreported due to incomplete data.
# 13808              1152              Underreported due to incomplete data.
# 13809              1003  Numbers may differ from published reports usin...
# 13810            100769              Underreported due to incomplete data.
# 13811               429  Numbers may differ from published reports usin...
# 13812                22  Numbers may differ from published reports usin...
# 13813               377  Numbers may differ from published reports usin...
# 13814               383  Numbers may differ from published reports usin...
# 13815               435              Underreported due to incomplete data.
# 13816              1701              Underreported due to incomplete data.
# 13817             16936              Underreported due to incomplete data.
# 13818                67  Numbers may differ from published reports usin...
# 13819               863              Underreported due to incomplete data.
# 13820               407  Numbers may differ from published reports usin...
# 13821               773              Underreported due to incomplete data.
# 13822               295              Underreported due to incomplete data.
# 13823               672  Numbers may differ from published reports usin...
# 13824               236  Numbers may differ from published reports usin...
# 13825               420  Numbers may differ from published reports usin...
# 13826               679              Underreported due to incomplete data.
# 13827             15406  Numbers may differ from published reports usin...
# 13828              2038              Underreported due to incomplete data.
# 13829              1140              Underreported due to incomplete data.
# 13830               304              Underreported due to incomplete data.
# 13831                32  Numbers may differ from published reports usin...
# 13832               195  Numbers may differ from published reports usin...
# 13833                31  Numbers may differ from published reports usin...
# 13834               534  Numbers may differ from published reports usin...
# 13835              1195              Underreported due to incomplete data.
#
#                                                indicator      month  \
# 0               Natural & semi-synthetic opioids (T40.2)  September
# 1                                       Number of Deaths     August
# 2               Natural & semi-synthetic opioids (T40.2)   December
# 3      Natural, semi-synthetic, & synthetic opioids, ...   November
# 4                           Percent with drugs specified    January
# 5                                       Number of Deaths      March
# 6                            Opioids (T40.0-T40.4,T40.6)   November
# 7          Psychostimulants with abuse potential (T43.6)      March
# 8                                       Number of Deaths        May
# 9                                         Heroin (T40.1)      April
# 10                                     Methadone (T40.3)      April
# 11     Natural & semi-synthetic opioids, incl. methad...      March
# 12                                      Number of Deaths  September
# 13                        Number of Drug Overdose Deaths    January
# 14                          Percent with drugs specified        May
# 15                                      Number of Deaths        May
# 16                                      Number of Deaths        May
# 17                                     Methadone (T40.3)    January
# 18                                     Methadone (T40.3)       June
# 19                                     Methadone (T40.3)       June
# 20                                      Number of Deaths      March
# 21                        Number of Drug Overdose Deaths    January
# 22            Synthetic opioids, excl. methadone (T40.4)    October
# 23                                     Methadone (T40.3)       June
# 24     Natural & semi-synthetic opioids, incl. methad...  September
# 25                                     Methadone (T40.3)     August
# 26         Psychostimulants with abuse potential (T43.6)       July
# 27                          Percent with drugs specified    January
# 28            Synthetic opioids, excl. methadone (T40.4)     August
# 29                                      Number of Deaths   December
# ...                                                  ...        ...
# 13806  Natural & semi-synthetic opioids, incl. methad...       June
# 13807                     Number of Drug Overdose Deaths     August
# 13808                        Opioids (T40.0-T40.4,T40.6)       July
# 13809  Natural, semi-synthetic, & synthetic opioids, ...   November
# 13810                                   Number of Deaths   February
# 13811  Natural & semi-synthetic opioids, incl. methad...   November
# 13812  Natural & semi-synthetic opioids, incl. methad...    January
# 13813  Natural, semi-synthetic, & synthetic opioids, ...      April
# 13814  Natural, semi-synthetic, & synthetic opioids, ...   February
# 13815           Natural & semi-synthetic opioids (T40.2)       July
# 13816                     Number of Drug Overdose Deaths      April
# 13817  Natural & semi-synthetic opioids, incl. methad...    January
# 13818  Natural & semi-synthetic opioids, incl. methad...       July
# 13819         Synthetic opioids, excl. methadone (T40.4)       June
# 13820  Natural & semi-synthetic opioids, incl. methad...   November
# 13821                        Opioids (T40.0-T40.4,T40.6)      April
# 13822  Natural & semi-synthetic opioids, incl. methad...    January
# 13823  Natural, semi-synthetic, & synthetic opioids, ...      March
# 13824  Natural, semi-synthetic, & synthetic opioids, ...        May
# 13825  Natural & semi-synthetic opioids, incl. methad...   February
# 13826                                    Cocaine (T40.5)       July
# 13827  Natural & semi-synthetic opioids, incl. methad...    October
# 13828                        Opioids (T40.0-T40.4,T40.6)    January
# 13829                     Number of Drug Overdose Deaths       June
# 13830  Natural, semi-synthetic, & synthetic opioids, ...       July
# 13831  Natural & semi-synthetic opioids, incl. methad...       June
# 13832  Natural & semi-synthetic opioids, incl. methad...      April
# 13833  Natural & semi-synthetic opioids, incl. methad...     August
# 13834  Natural, semi-synthetic, & synthetic opioids, ...   December
# 13835                        Opioids (T40.0-T40.4,T40.6)   February
#
#       percent_complete percent_pending_investigation predicted_value state  \
# 0                  100                             0              25    VT
# 1                  100             0.364995993946408             NaN    NC
# 2                  100            0.0042288662409608             273    NV
# 3                  100            0.0339520144861929             238    NM
# 4                  100             0.164728689174528             NaN    US
# 5                  100             0.284871736142923             NaN    TN
# 6                  100                             0              80    VT
# 7                  100            0.0345811359903173               7    NH
# 8                  100            0.0879163817524665             NaN    MT
# 9                  100           0.00754517674576527             293    WA
# 10                 100            0.0214392910741085              42    ME
# 11                 100                             0              33    VT
# 12                 100                             0             NaN    DE
# 13                 100             0.033776176536816            1170    IN
# 14                 100            0.0222102944714875             NaN    YC
# 15                 100            0.0229643724165081             NaN    MO
# 16                 100            0.0796976320142973             NaN    GA
# 17                 100                             0              29    ME
# 18                 100            0.0142694063926941              40    ME
# 19                 100           0.00787835815016151              52    NV
# 20                 100                             0             NaN    ME
# 21                 100            0.0155863819554229            1106    KY
# 22                 100                             0              51    NV
# 23                 100            0.0226269940038466              61    OR
# 24                 100           0.00552201443086438             357    WA
# 25                 100            0.0105358535094928             167    MD
# 26                 100           0.00785453402976868             298    NV
# 27                 100            0.0391615694465165             NaN    YC
# 28                 100             0.148719883671925            8455    US
# 29                 100            0.0261088084592539             NaN    CT
# ...                ...                           ...             ...   ...
# 13806              100            0.0677441207780896             109    RI
# 13807              100                             0             673    MN
# 13808              100            0.0912475900334084            1174    VA
# 13809              100            0.0415479582146249            1012    VA
# 13810              100             0.521985928212049             NaN    NY
# 13811              100            0.0387161003668811             434    YC
# 13812              100                             0              23    VT
# 13813              100             0.807369276618803             433    UT
# 13814              100            0.0184521299029945             385    OK
# 13815              100             0.610767686373963             480    NC
# 13816              100            0.0740382581366535            1722    IN
# 13817              100             0.150940769196691           17234    US
# 13818              100            0.0492610837438424              68    NH
# 13819              100             0.150914578711953             894    YC
# 13820              100             0.013802834181952             410    VA
# 13821              100             0.178394048125849             795    SC
# 13822              100            0.0891611102496511             298    NV
# 13823              100            0.0085437224998932             675    MD
# 13824              100            0.0911317423249986             240    NM
# 13825              100             0.384615384615385             446    UT
# 13826              100             0.610767686373963             735    NC
# 13827              100              0.15293214597802           15806    US
# 13828              100            0.0360281019194972            2040    MD
# 13829              100             0.228811493088768            1181    WI
# 13830              100             0.147475453098925             314    NV
# 13831              100                             0              33    VT
# 13832              100            0.0674574175051998             198    NM
# 13833              100                             0              32    VT
# 13834              100            0.0381979076035057             539    SC
# 13835              100            0.0655510843241865            1207    YC
#
#       state_name  year month-year
# 0             VT  2015   Sep-2015
# 1             NC  2015   Aug-2015
# 2             NV  2015   Dec-2015
# 3             NM  2016   Nov-2016
# 4             US  2017   Jan-2017
# 5             TN  2016   Mar-2016
# 6             VT  2015   Nov-2015
# 7             NH  2016   Mar-2016
# 8             MT  2017   May-2017
# 9             WA  2015   Apr-2015
# 10            ME  2015   Apr-2015
# 11            VT  2018   Mar-2018
# 12            DE  2016   Sep-2016
# 13            IN  2015   Jan-2015
# 14            YC  2015   May-2015
# 15            MO  2016   May-2016
# 16            GA  2017   May-2017
# 17            ME  2018   Jan-2018
# 18            ME  2015   Jun-2015
# 19            NV  2017   Jun-2017
# 20            ME  2016   Mar-2016
# 21            KY  2015   Jan-2015
# 22            NV  2016   Oct-2016
# 23            OR  2015   Jun-2015
# 24            WA  2015   Sep-2015
# 25            MD  2015   Aug-2015
# 26            NV  2017   Jul-2017
# 27            YC  2016   Jan-2016
# 28            US  2015   Aug-2015
# 29            CT  2016   Dec-2016
# ...          ...   ...        ...
# 13806         RI  2017   Jun-2017
# 13807         MN  2018   Aug-2018
# 13808         VA  2018   Jul-2018
# 13809         VA  2017   Nov-2017
# 13810         NY  2018   Feb-2018
# 13811         YC  2017   Nov-2017
# 13812         VT  2015   Jan-2015
# 13813         UT  2017   Apr-2017
# 13814         OK  2016   Feb-2016
# 13815         NC  2018   Jul-2018
# 13816         IN  2018   Apr-2018
# 13817         US  2018   Jan-2018
# 13818         NH  2017   Jul-2017
# 13819         YC  2018   Jun-2018
# 13820         VA  2016   Nov-2016
# 13821         SC  2018   Apr-2018
# 13822         NV  2018   Jan-2018
# 13823         MD  2015   Mar-2015
# 13824         NM  2016   May-2016
# 13825         UT  2016   Feb-2016
# 13826         NC  2018   Jul-2018
# 13827         US  2015   Oct-2015
# 13828         MD  2018   Jan-2018
# 13829         WI  2018   Jun-2018
# 13830         NV  2018   Jul-2018
# 13831         VT  2016   Jun-2016
# 13832         NM  2017   Apr-2017
# 13833         VT  2015   Aug-2015
# 13834         SC  2016   Dec-2016
# 13835         YC  2018   Feb-2018
#
# [13836 rows x 11 columns]

# %%
drug_df=drug_df.sort_values(by=['state','month-year'])
drug_df
# Out:
#              data_value                                           footnote  \
# 887                 126  Numbers may differ from published reports usin...
# 5174               4133  Numbers may differ from published reports usin...
# 6338                132  Numbers may differ from published reports usin...
# 7268               4262  Numbers may differ from published reports usin...
# 3921                117  Numbers may differ from published reports usin...
# 4660               4325  Numbers may differ from published reports usin...
# 678                4341              Underreported due to incomplete data.
# 11153               141              Underreported due to incomplete data.
# 13124               142              Underreported due to incomplete data.
# 2148               4222  Numbers may differ from published reports usin...
# 8067                124  Numbers may differ from published reports usin...
# 3077               4276  Numbers may differ from published reports usin...
# 7754                138  Numbers may differ from published reports usin...
# 1172               4234  Numbers may differ from published reports usin...
# 7599                137  Numbers may differ from published reports usin...
# 292                 110              Underreported due to incomplete data.
# 461                4382              Underreported due to incomplete data.
# 532                 121  Numbers may differ from published reports usin...
# 759                4193  Numbers may differ from published reports usin...
# 4912                129  Numbers may differ from published reports usin...
# 5609               4355  Numbers may differ from published reports usin...
# 533                 141  Numbers may differ from published reports usin...
# 1323               4279  Numbers may differ from published reports usin...
# 527                 127  Numbers may differ from published reports usin...
# 4963               4084  Numbers may differ from published reports usin...
# 657                 128  Numbers may differ from published reports usin...
# 7093               4198  Numbers may differ from published reports usin...
# 762                4347  Numbers may differ from published reports usin...
# 5392                124  Numbers may differ from published reports usin...
# 264                 139              Underreported due to incomplete data.
# ...                 ...                                                ...
# 5981                 38  Numbers may differ from published reports usin...
# 6456                136  Numbers may differ from published reports usin...
# 6560              54449  Numbers may differ from published reports usin...
# 8193                325  Numbers may differ from published reports usin...
# 11225               360  Numbers may differ from published reports usin...
# 12635               384  Numbers may differ from published reports usin...
# 372                 749  Numbers may differ from published reports usin...
# 3354                147  Numbers may differ from published reports usin...
# 3764                442  Numbers may differ from published reports usin...
# 5517                 63  Numbers may differ from published reports usin...
# 6154   99.2372234935164  Numbers may differ from published reports usin...
# 6176                540  Numbers may differ from published reports usin...
# 6284                412  Numbers may differ from published reports usin...
# 6562                476  Numbers may differ from published reports usin...
# 6748                305  Numbers may differ from published reports usin...
# 7602               1038  Numbers may differ from published reports usin...
# 8160              53533  Numbers may differ from published reports usin...
# 10407              1311  Numbers may differ from published reports usin...
# 1820                317  Numbers may differ from published reports usin...
# 2247               1215  Numbers may differ from published reports usin...
# 2812                634  Numbers may differ from published reports usin...
# 3141              54331  Numbers may differ from published reports usin...
# 3549                 65  Numbers may differ from published reports usin...
# 6570    99.669749009247  Numbers may differ from published reports usin...
# 6690                754  Numbers may differ from published reports usin...
# 7455               1016  Numbers may differ from published reports usin...
# 7610                615  Numbers may differ from published reports usin...
# 10703              1514  Numbers may differ from published reports usin...
# 11330               172  Numbers may differ from published reports usin...
# 12862               446  Numbers may differ from published reports usin...
#
#                                                indicator      month  \
# 887                       Number of Drug Overdose Deaths      April
# 5174                                    Number of Deaths      April
# 6338                      Number of Drug Overdose Deaths      April
# 7268                                    Number of Deaths      April
# 3921                      Number of Drug Overdose Deaths      April
# 4660                                    Number of Deaths      April
# 678                                     Number of Deaths      April
# 11153                     Number of Drug Overdose Deaths      April
# 13124                     Number of Drug Overdose Deaths      April
# 2148                                    Number of Deaths     August
# 8067                      Number of Drug Overdose Deaths     August
# 3077                                    Number of Deaths     August
# 7754                      Number of Drug Overdose Deaths     August
# 1172                                    Number of Deaths     August
# 7599                      Number of Drug Overdose Deaths     August
# 292                       Number of Drug Overdose Deaths     August
# 461                                     Number of Deaths     August
# 532                       Number of Drug Overdose Deaths   December
# 759                                     Number of Deaths   December
# 4912                      Number of Drug Overdose Deaths   December
# 5609                                    Number of Deaths   December
# 533                       Number of Drug Overdose Deaths   December
# 1323                                    Number of Deaths   December
# 527                       Number of Drug Overdose Deaths   February
# 4963                                    Number of Deaths   February
# 657                       Number of Drug Overdose Deaths   February
# 7093                                    Number of Deaths   February
# 762                                     Number of Deaths   February
# 5392                      Number of Drug Overdose Deaths   February
# 264                       Number of Drug Overdose Deaths   February
# ...                                                  ...        ...
# 5981       Psychostimulants with abuse potential (T43.6)  September
# 6456                                   Methadone (T40.3)  September
# 6560                                    Number of Deaths  September
# 8193   Natural & semi-synthetic opioids, incl. methad...  September
# 11225                                     Heroin (T40.1)  September
# 12635  Natural, semi-synthetic, & synthetic opioids, ...  September
# 372    Natural, semi-synthetic, & synthetic opioids, ...  September
# 3354                                   Methadone (T40.3)  September
# 3764                                     Cocaine (T40.5)  September
# 5517       Psychostimulants with abuse potential (T43.6)  September
# 6154                        Percent with drugs specified  September
# 6176                                      Heroin (T40.1)  September
# 6284   Natural & semi-synthetic opioids, incl. methad...  September
# 6562          Synthetic opioids, excl. methadone (T40.4)  September
# 6748            Natural & semi-synthetic opioids (T40.2)  September
# 7602                         Opioids (T40.0-T40.4,T40.6)  September
# 8160                                    Number of Deaths  September
# 10407                     Number of Drug Overdose Deaths  September
# 1820            Natural & semi-synthetic opioids (T40.2)  September
# 2247                         Opioids (T40.0-T40.4,T40.6)  September
# 2812                                      Heroin (T40.1)  September
# 3141                                    Number of Deaths  September
# 3549       Psychostimulants with abuse potential (T43.6)  September
# 6570                        Percent with drugs specified  September
# 6690          Synthetic opioids, excl. methadone (T40.4)  September
# 7455   Natural, semi-synthetic, & synthetic opioids, ...  September
# 7610                                     Cocaine (T40.5)  September
# 10703                     Number of Drug Overdose Deaths  September
# 11330                                  Methadone (T40.3)  September
# 12862  Natural & semi-synthetic opioids, incl. methad...  September
#
#       percent_complete percent_pending_investigation predicted_value state  \
# 887                100                             0             127    AK
# 5174               100                             0             NaN    AK
# 6338               100                             0             133    AK
# 7268               100                             0             NaN    AK
# 3921               100             0.069364161849711             119    AK
# 4660               100             0.069364161849711             NaN    AK
# 678                100                             0             NaN    AK
# 11153              100                             0             142    AK
# 13124              100                             0             143    AK
# 2148               100                             0             NaN    AK
# 8067               100                             0             125    AK
# 3077               100            0.0233863423760524             NaN    AK
# 7754               100            0.0233863423760524             139    AK
# 1172               100            0.0472366556447803             NaN    AK
# 7599               100            0.0472366556447803             139    AK
# 292                100                             0             111    AK
# 461                100                             0             NaN    AK
# 532                100                             0             122    AK
# 759                100                             0             NaN    AK
# 4912               100             0.068886337543054             131    AK
# 5609               100             0.068886337543054             NaN    AK
# 533                100                             0             142    AK
# 1323               100                             0             NaN    AK
# 527                100                             0             128    AK
# 4963               100                             0             NaN    AK
# 657                100                             0             129    AK
# 7093               100                             0             NaN    AK
# 762                100            0.0690131124913734             NaN    AK
# 5392               100            0.0690131124913734             126    AK
# 264                100                             0             139    AK
# ...                ...                           ...             ...   ...
# 5981               100            0.0367316204154346              39    YC
# 6456               100            0.0367316204154346             138    YC
# 6560               100            0.0367316204154346             NaN    YC
# 8193               100            0.0367316204154346             328    YC
# 11225              100            0.0367316204154346             362    YC
# 12635              100            0.0367316204154346             388    YC
# 372                100            0.0373601330020735             755    YC
# 3354               100            0.0373601330020735             149    YC
# 3764               100            0.0373601330020735             468    YC
# 5517               100            0.0373601330020735              64    YC
# 6154               100            0.0373601330020735             NaN    YC
# 6176               100            0.0373601330020735             543    YC
# 6284               100            0.0373601330020735             416    YC
# 6562               100            0.0373601330020735             481    YC
# 6748               100            0.0373601330020735             309    YC
# 7602               100            0.0373601330020735            1045    YC
# 8160               100            0.0373601330020735             NaN    YC
# 10407              100            0.0373601330020735            1320    YC
# 1820               100            0.0220868380850711             320    YC
# 2247               100            0.0220868380850711            1221    YC
# 2812               100            0.0220868380850711             637    YC
# 3141               100            0.0220868380850711             NaN    YC
# 3549               100            0.0220868380850711              66    YC
# 6570               100            0.0220868380850711             NaN    YC
# 6690               100            0.0220868380850711             760    YC
# 7455               100            0.0220868380850711            1022    YC
# 7610               100            0.0220868380850711             650    YC
# 10703              100            0.0220868380850711            1521    YC
# 11330              100            0.0220868380850711             174    YC
# 12862              100            0.0220868380850711             450    YC
#
#       state_name  year month-year
# 887           AK  2015   Apr-2015
# 5174          AK  2015   Apr-2015
# 6338          AK  2016   Apr-2016
# 7268          AK  2016   Apr-2016
# 3921          AK  2017   Apr-2017
# 4660          AK  2017   Apr-2017
# 678           AK  2018   Apr-2018
# 11153         AK  2018   Apr-2018
# 13124         AK  2018   Apr-2018
# 2148          AK  2015   Aug-2015
# 8067          AK  2015   Aug-2015
# 3077          AK  2016   Aug-2016
# 7754          AK  2016   Aug-2016
# 1172          AK  2017   Aug-2017
# 7599          AK  2017   Aug-2017
# 292           AK  2018   Aug-2018
# 461           AK  2018   Aug-2018
# 532           AK  2015   Dec-2015
# 759           AK  2015   Dec-2015
# 4912          AK  2016   Dec-2016
# 5609          AK  2016   Dec-2016
# 533           AK  2017   Dec-2017
# 1323          AK  2017   Dec-2017
# 527           AK  2015   Feb-2015
# 4963          AK  2015   Feb-2015
# 657           AK  2016   Feb-2016
# 7093          AK  2016   Feb-2016
# 762           AK  2017   Feb-2017
# 5392          AK  2017   Feb-2017
# 264           AK  2018   Feb-2018
# ...          ...   ...        ...
# 5981          YC  2015   Sep-2015
# 6456          YC  2015   Sep-2015
# 6560          YC  2015   Sep-2015
# 8193          YC  2015   Sep-2015
# 11225         YC  2015   Sep-2015
# 12635         YC  2015   Sep-2015
# 372           YC  2016   Sep-2016
# 3354          YC  2016   Sep-2016
# 3764          YC  2016   Sep-2016
# 5517          YC  2016   Sep-2016
# 6154          YC  2016   Sep-2016
# 6176          YC  2016   Sep-2016
# 6284          YC  2016   Sep-2016
# 6562          YC  2016   Sep-2016
# 6748          YC  2016   Sep-2016
# 7602          YC  2016   Sep-2016
# 8160          YC  2016   Sep-2016
# 10407         YC  2016   Sep-2016
# 1820          YC  2017   Sep-2017
# 2247          YC  2017   Sep-2017
# 2812          YC  2017   Sep-2017
# 3141          YC  2017   Sep-2017
# 3549          YC  2017   Sep-2017
# 6570          YC  2017   Sep-2017
# 6690          YC  2017   Sep-2017
# 7455          YC  2017   Sep-2017
# 7610          YC  2017   Sep-2017
# 10703         YC  2017   Sep-2017
# 11330         YC  2017   Sep-2017
# 12862         YC  2017   Sep-2017
#
# [13836 rows x 11 columns]

# %%
drug_df = drug_df.set_index(['state', 'month-year'], inplace=False)
drug_df
# Out:
#                         data_value  \
# state month-year
# AK    Apr-2015                 126
#       Apr-2015                4133
#       Apr-2016                 132
#       Apr-2016                4262
#       Apr-2017                 117
#       Apr-2017                4325
#       Apr-2018                4341
#       Apr-2018                 141
#       Apr-2018                 142
#       Aug-2015                4222
#       Aug-2015                 124
#       Aug-2016                4276
#       Aug-2016                 138
#       Aug-2017                4234
#       Aug-2017                 137
#       Aug-2018                 110
#       Aug-2018                4382
#       Dec-2015                 121
#       Dec-2015                4193
#       Dec-2016                 129
#       Dec-2016                4355
#       Dec-2017                 141
#       Dec-2017                4279
#       Feb-2015                 127
#       Feb-2015                4084
#       Feb-2016                 128
#       Feb-2016                4198
#       Feb-2017                4347
#       Feb-2017                 124
#       Feb-2018                 139
# ...                            ...
# YC    Sep-2015                  38
#       Sep-2015                 136
#       Sep-2015               54449
#       Sep-2015                 325
#       Sep-2015                 360
#       Sep-2015                 384
#       Sep-2016                 749
#       Sep-2016                 147
#       Sep-2016                 442
#       Sep-2016                  63
#       Sep-2016    99.2372234935164
#       Sep-2016                 540
#       Sep-2016                 412
#       Sep-2016                 476
#       Sep-2016                 305
#       Sep-2016                1038
#       Sep-2016               53533
#       Sep-2016                1311
#       Sep-2017                 317
#       Sep-2017                1215
#       Sep-2017                 634
#       Sep-2017               54331
#       Sep-2017                  65
#       Sep-2017     99.669749009247
#       Sep-2017                 754
#       Sep-2017                1016
#       Sep-2017                 615
#       Sep-2017                1514
#       Sep-2017                 172
#       Sep-2017                 446
#
#                                                            footnote  \
# state month-year
# AK    Apr-2015    Numbers may differ from published reports usin...
#       Apr-2015    Numbers may differ from published reports usin...
#       Apr-2016    Numbers may differ from published reports usin...
#       Apr-2016    Numbers may differ from published reports usin...
#       Apr-2017    Numbers may differ from published reports usin...
#       Apr-2017    Numbers may differ from published reports usin...
#       Apr-2018                Underreported due to incomplete data.
#       Apr-2018                Underreported due to incomplete data.
#       Apr-2018                Underreported due to incomplete data.
#       Aug-2015    Numbers may differ from published reports usin...
#       Aug-2015    Numbers may differ from published reports usin...
#       Aug-2016    Numbers may differ from published reports usin...
#       Aug-2016    Numbers may differ from published reports usin...
#       Aug-2017    Numbers may differ from published reports usin...
#       Aug-2017    Numbers may differ from published reports usin...
#       Aug-2018                Underreported due to incomplete data.
#       Aug-2018                Underreported due to incomplete data.
#       Dec-2015    Numbers may differ from published reports usin...
#       Dec-2015    Numbers may differ from published reports usin...
#       Dec-2016    Numbers may differ from published reports usin...
#       Dec-2016    Numbers may differ from published reports usin...
#       Dec-2017    Numbers may differ from published reports usin...
#       Dec-2017    Numbers may differ from published reports usin...
#       Feb-2015    Numbers may differ from published reports usin...
#       Feb-2015    Numbers may differ from published reports usin...
#       Feb-2016    Numbers may differ from published reports usin...
#       Feb-2016    Numbers may differ from published reports usin...
#       Feb-2017    Numbers may differ from published reports usin...
#       Feb-2017    Numbers may differ from published reports usin...
#       Feb-2018                Underreported due to incomplete data.
# ...                                                             ...
# YC    Sep-2015    Numbers may differ from published reports usin...
#       Sep-2015    Numbers may differ from published reports usin...
#       Sep-2015    Numbers may differ from published reports usin...
#       Sep-2015    Numbers may differ from published reports usin...
#       Sep-2015    Numbers may differ from published reports usin...
#       Sep-2015    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#
#                                                           indicator  \
# state month-year
# AK    Apr-2015                       Number of Drug Overdose Deaths
#       Apr-2015                                     Number of Deaths
#       Apr-2016                       Number of Drug Overdose Deaths
#       Apr-2016                                     Number of Deaths
#       Apr-2017                       Number of Drug Overdose Deaths
#       Apr-2017                                     Number of Deaths
#       Apr-2018                                     Number of Deaths
#       Apr-2018                       Number of Drug Overdose Deaths
#       Apr-2018                       Number of Drug Overdose Deaths
#       Aug-2015                                     Number of Deaths
#       Aug-2015                       Number of Drug Overdose Deaths
#       Aug-2016                                     Number of Deaths
#       Aug-2016                       Number of Drug Overdose Deaths
#       Aug-2017                                     Number of Deaths
#       Aug-2017                       Number of Drug Overdose Deaths
#       Aug-2018                       Number of Drug Overdose Deaths
#       Aug-2018                                     Number of Deaths
#       Dec-2015                       Number of Drug Overdose Deaths
#       Dec-2015                                     Number of Deaths
#       Dec-2016                       Number of Drug Overdose Deaths
#       Dec-2016                                     Number of Deaths
#       Dec-2017                       Number of Drug Overdose Deaths
#       Dec-2017                                     Number of Deaths
#       Feb-2015                       Number of Drug Overdose Deaths
#       Feb-2015                                     Number of Deaths
#       Feb-2016                       Number of Drug Overdose Deaths
#       Feb-2016                                     Number of Deaths
#       Feb-2017                                     Number of Deaths
#       Feb-2017                       Number of Drug Overdose Deaths
#       Feb-2018                       Number of Drug Overdose Deaths
# ...                                                             ...
# YC    Sep-2015        Psychostimulants with abuse potential (T43.6)
#       Sep-2015                                    Methadone (T40.3)
#       Sep-2015                                     Number of Deaths
#       Sep-2015    Natural & semi-synthetic opioids, incl. methad...
#       Sep-2015                                       Heroin (T40.1)
#       Sep-2015    Natural, semi-synthetic, & synthetic opioids, ...
#       Sep-2016    Natural, semi-synthetic, & synthetic opioids, ...
#       Sep-2016                                    Methadone (T40.3)
#       Sep-2016                                      Cocaine (T40.5)
#       Sep-2016        Psychostimulants with abuse potential (T43.6)
#       Sep-2016                         Percent with drugs specified
#       Sep-2016                                       Heroin (T40.1)
#       Sep-2016    Natural & semi-synthetic opioids, incl. methad...
#       Sep-2016           Synthetic opioids, excl. methadone (T40.4)
#       Sep-2016             Natural & semi-synthetic opioids (T40.2)
#       Sep-2016                          Opioids (T40.0-T40.4,T40.6)
#       Sep-2016                                     Number of Deaths
#       Sep-2016                       Number of Drug Overdose Deaths
#       Sep-2017             Natural & semi-synthetic opioids (T40.2)
#       Sep-2017                          Opioids (T40.0-T40.4,T40.6)
#       Sep-2017                                       Heroin (T40.1)
#       Sep-2017                                     Number of Deaths
#       Sep-2017        Psychostimulants with abuse potential (T43.6)
#       Sep-2017                         Percent with drugs specified
#       Sep-2017           Synthetic opioids, excl. methadone (T40.4)
#       Sep-2017    Natural, semi-synthetic, & synthetic opioids, ...
#       Sep-2017                                      Cocaine (T40.5)
#       Sep-2017                       Number of Drug Overdose Deaths
#       Sep-2017                                    Methadone (T40.3)
#       Sep-2017    Natural & semi-synthetic opioids, incl. methad...
#
#                       month percent_complete percent_pending_investigation  \
# state month-year
# AK    Apr-2015        April              100                             0
#       Apr-2015        April              100                             0
#       Apr-2016        April              100                             0
#       Apr-2016        April              100                             0
#       Apr-2017        April              100             0.069364161849711
#       Apr-2017        April              100             0.069364161849711
#       Apr-2018        April              100                             0
#       Apr-2018        April              100                             0
#       Apr-2018        April              100                             0
#       Aug-2015       August              100                             0
#       Aug-2015       August              100                             0
#       Aug-2016       August              100            0.0233863423760524
#       Aug-2016       August              100            0.0233863423760524
#       Aug-2017       August              100            0.0472366556447803
#       Aug-2017       August              100            0.0472366556447803
#       Aug-2018       August              100                             0
#       Aug-2018       August              100                             0
#       Dec-2015     December              100                             0
#       Dec-2015     December              100                             0
#       Dec-2016     December              100             0.068886337543054
#       Dec-2016     December              100             0.068886337543054
#       Dec-2017     December              100                             0
#       Dec-2017     December              100                             0
#       Feb-2015     February              100                             0
#       Feb-2015     February              100                             0
#       Feb-2016     February              100                             0
#       Feb-2016     February              100                             0
#       Feb-2017     February              100            0.0690131124913734
#       Feb-2017     February              100            0.0690131124913734
#       Feb-2018     February              100                             0
# ...                     ...              ...                           ...
# YC    Sep-2015    September              100            0.0367316204154346
#       Sep-2015    September              100            0.0367316204154346
#       Sep-2015    September              100            0.0367316204154346
#       Sep-2015    September              100            0.0367316204154346
#       Sep-2015    September              100            0.0367316204154346
#       Sep-2015    September              100            0.0367316204154346
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2016    September              100            0.0373601330020735
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#       Sep-2017    September              100            0.0220868380850711
#
#                  predicted_value state_name  year
# state month-year
# AK    Apr-2015               127         AK  2015
#       Apr-2015               NaN         AK  2015
#       Apr-2016               133         AK  2016
#       Apr-2016               NaN         AK  2016
#       Apr-2017               119         AK  2017
#       Apr-2017               NaN         AK  2017
#       Apr-2018               NaN         AK  2018
#       Apr-2018               142         AK  2018
#       Apr-2018               143         AK  2018
#       Aug-2015               NaN         AK  2015
#       Aug-2015               125         AK  2015
#       Aug-2016               NaN         AK  2016
#       Aug-2016               139         AK  2016
#       Aug-2017               NaN         AK  2017
#       Aug-2017               139         AK  2017
#       Aug-2018               111         AK  2018
#       Aug-2018               NaN         AK  2018
#       Dec-2015               122         AK  2015
#       Dec-2015               NaN         AK  2015
#       Dec-2016               131         AK  2016
#       Dec-2016               NaN         AK  2016
#       Dec-2017               142         AK  2017
#       Dec-2017               NaN         AK  2017
#       Feb-2015               128         AK  2015
#       Feb-2015               NaN         AK  2015
#       Feb-2016               129         AK  2016
#       Feb-2016               NaN         AK  2016
#       Feb-2017               NaN         AK  2017
#       Feb-2017               126         AK  2017
#       Feb-2018               139         AK  2018
# ...                          ...        ...   ...
# YC    Sep-2015                39         YC  2015
#       Sep-2015               138         YC  2015
#       Sep-2015               NaN         YC  2015
#       Sep-2015               328         YC  2015
#       Sep-2015               362         YC  2015
#       Sep-2015               388         YC  2015
#       Sep-2016               755         YC  2016
#       Sep-2016               149         YC  2016
#       Sep-2016               468         YC  2016
#       Sep-2016                64         YC  2016
#       Sep-2016               NaN         YC  2016
#       Sep-2016               543         YC  2016
#       Sep-2016               416         YC  2016
#       Sep-2016               481         YC  2016
#       Sep-2016               309         YC  2016
#       Sep-2016              1045         YC  2016
#       Sep-2016               NaN         YC  2016
#       Sep-2016              1320         YC  2016
#       Sep-2017               320         YC  2017
#       Sep-2017              1221         YC  2017
#       Sep-2017               637         YC  2017
#       Sep-2017               NaN         YC  2017
#       Sep-2017                66         YC  2017
#       Sep-2017               NaN         YC  2017
#       Sep-2017               760         YC  2017
#       Sep-2017              1022         YC  2017
#       Sep-2017               650         YC  2017
#       Sep-2017              1521         YC  2017
#       Sep-2017               174         YC  2017
#       Sep-2017               450         YC  2017
#
# [13836 rows x 9 columns]

# %%
drug_df=drug_df[drug_df.indicator == 'Number of Deaths']
drug_df
# Out:
#                  data_value  \
# state month-year
# AK    Apr-2015         4133
#       Apr-2016         4262
#       Apr-2017         4325
#       Apr-2018         4341
#       Aug-2015         4222
#       Aug-2016         4276
#       Aug-2017         4234
#       Aug-2018         4382
#       Dec-2015         4193
#       Dec-2016         4355
#       Dec-2017         4279
#       Feb-2015         4084
#       Feb-2016         4198
#       Feb-2017         4347
#       Feb-2018         4304
#       Jan-2015         4034
#       Jan-2016         4213
#       Jan-2017         4374
#       Jan-2018         4260
#       Jul-2015         4220
#       Jul-2016         4269
#       Jul-2017         4236
#       Jul-2018         4337
#       Jul-2018         4333
#       Jun-2015         4201
#       Jun-2016         4261
#       Jun-2017         4276
#       Jun-2018         4309
#       Jun-2018         4307
#       Mar-2015         4101
# ...                     ...
# YC    Jan-2017        54566
#       Jan-2018        54737
#       Jul-2015        54291
#       Jul-2016        53502
#       Jul-2017        54200
#       Jul-2018        55034
#       Jul-2018        55035
#       Jun-2015        54107
#       Jun-2016        53435
#       Jun-2017        54245
#       Jun-2018        54998
#       Jun-2018        54997
#       Mar-2015        54149
#       Mar-2016        53547
#       Mar-2017        54145
#       Mar-2018        54993
#       May-2015        54029
#       May-2016        53496
#       May-2017        54194
#       May-2018        54916
#       May-2018        54917
#       Nov-2015        54320
#       Nov-2016        53882
#       Nov-2017        54241
#       Oct-2015        54572
#       Oct-2016        53545
#       Oct-2017        54287
#       Sep-2015        54449
#       Sep-2016        53533
#       Sep-2017        54331
#
#                                                            footnote  \
# state month-year
# AK    Apr-2015    Numbers may differ from published reports usin...
#       Apr-2016    Numbers may differ from published reports usin...
#       Apr-2017    Numbers may differ from published reports usin...
#       Apr-2018                Underreported due to incomplete data.
#       Aug-2015    Numbers may differ from published reports usin...
#       Aug-2016    Numbers may differ from published reports usin...
#       Aug-2017    Numbers may differ from published reports usin...
#       Aug-2018                Underreported due to incomplete data.
#       Dec-2015    Numbers may differ from published reports usin...
#       Dec-2016    Numbers may differ from published reports usin...
#       Dec-2017    Numbers may differ from published reports usin...
#       Feb-2015    Numbers may differ from published reports usin...
#       Feb-2016    Numbers may differ from published reports usin...
#       Feb-2017    Numbers may differ from published reports usin...
#       Feb-2018                Underreported due to incomplete data.
#       Jan-2015    Numbers may differ from published reports usin...
#       Jan-2016    Numbers may differ from published reports usin...
#       Jan-2017    Numbers may differ from published reports usin...
#       Jan-2018                Underreported due to incomplete data.
#       Jul-2015    Numbers may differ from published reports usin...
#       Jul-2016    Numbers may differ from published reports usin...
#       Jul-2017    Numbers may differ from published reports usin...
#       Jul-2018                Underreported due to incomplete data.
#       Jul-2018                Underreported due to incomplete data.
#       Jun-2015    Numbers may differ from published reports usin...
#       Jun-2016    Numbers may differ from published reports usin...
#       Jun-2017    Numbers may differ from published reports usin...
#       Jun-2018                Underreported due to incomplete data.
#       Jun-2018                Underreported due to incomplete data.
#       Mar-2015    Numbers may differ from published reports usin...
# ...                                                             ...
# YC    Jan-2017    Numbers may differ from published reports usin...
#       Jan-2018                Underreported due to incomplete data.
#       Jul-2015    Numbers may differ from published reports usin...
#       Jul-2016    Numbers may differ from published reports usin...
#       Jul-2017    Numbers may differ from published reports usin...
#       Jul-2018                Underreported due to incomplete data.
#       Jul-2018                Underreported due to incomplete data.
#       Jun-2015    Numbers may differ from published reports usin...
#       Jun-2016    Numbers may differ from published reports usin...
#       Jun-2017    Numbers may differ from published reports usin...
#       Jun-2018                Underreported due to incomplete data.
#       Jun-2018                Underreported due to incomplete data.
#       Mar-2015    Numbers may differ from published reports usin...
#       Mar-2016    Numbers may differ from published reports usin...
#       Mar-2017    Numbers may differ from published reports usin...
#       Mar-2018                Underreported due to incomplete data.
#       May-2015    Numbers may differ from published reports usin...
#       May-2016    Numbers may differ from published reports usin...
#       May-2017    Numbers may differ from published reports usin...
#       May-2018                Underreported due to incomplete data.
#       May-2018                Underreported due to incomplete data.
#       Nov-2015    Numbers may differ from published reports usin...
#       Nov-2016    Numbers may differ from published reports usin...
#       Nov-2017    Numbers may differ from published reports usin...
#       Oct-2015    Numbers may differ from published reports usin...
#       Oct-2016    Numbers may differ from published reports usin...
#       Oct-2017    Numbers may differ from published reports usin...
#       Sep-2015    Numbers may differ from published reports usin...
#       Sep-2016    Numbers may differ from published reports usin...
#       Sep-2017    Numbers may differ from published reports usin...
#
#                          indicator      month percent_complete  \
# state month-year
# AK    Apr-2015    Number of Deaths      April              100
#       Apr-2016    Number of Deaths      April              100
#       Apr-2017    Number of Deaths      April              100
#       Apr-2018    Number of Deaths      April              100
#       Aug-2015    Number of Deaths     August              100
#       Aug-2016    Number of Deaths     August              100
#       Aug-2017    Number of Deaths     August              100
#       Aug-2018    Number of Deaths     August              100
#       Dec-2015    Number of Deaths   December              100
#       Dec-2016    Number of Deaths   December              100
#       Dec-2017    Number of Deaths   December              100
#       Feb-2015    Number of Deaths   February              100
#       Feb-2016    Number of Deaths   February              100
#       Feb-2017    Number of Deaths   February              100
#       Feb-2018    Number of Deaths   February              100
#       Jan-2015    Number of Deaths    January              100
#       Jan-2016    Number of Deaths    January              100
#       Jan-2017    Number of Deaths    January              100
#       Jan-2018    Number of Deaths    January              100
#       Jul-2015    Number of Deaths       July              100
#       Jul-2016    Number of Deaths       July              100
#       Jul-2017    Number of Deaths       July              100
#       Jul-2018    Number of Deaths       July              100
#       Jul-2018    Number of Deaths       July              100
#       Jun-2015    Number of Deaths       June              100
#       Jun-2016    Number of Deaths       June              100
#       Jun-2017    Number of Deaths       June              100
#       Jun-2018    Number of Deaths       June              100
#       Jun-2018    Number of Deaths       June              100
#       Mar-2015    Number of Deaths      March              100
# ...                            ...        ...              ...
# YC    Jan-2017    Number of Deaths    January              100
#       Jan-2018    Number of Deaths    January              100
#       Jul-2015    Number of Deaths       July              100
#       Jul-2016    Number of Deaths       July              100
#       Jul-2017    Number of Deaths       July              100
#       Jul-2018    Number of Deaths       July              100
#       Jul-2018    Number of Deaths       July              100
#       Jun-2015    Number of Deaths       June              100
#       Jun-2016    Number of Deaths       June              100
#       Jun-2017    Number of Deaths       June              100
#       Jun-2018    Number of Deaths       June              100
#       Jun-2018    Number of Deaths       June              100
#       Mar-2015    Number of Deaths      March              100
#       Mar-2016    Number of Deaths      March              100
#       Mar-2017    Number of Deaths      March              100
#       Mar-2018    Number of Deaths      March              100
#       May-2015    Number of Deaths        May              100
#       May-2016    Number of Deaths        May              100
#       May-2017    Number of Deaths        May              100
#       May-2018    Number of Deaths        May              100
#       May-2018    Number of Deaths        May              100
#       Nov-2015    Number of Deaths   November              100
#       Nov-2016    Number of Deaths   November              100
#       Nov-2017    Number of Deaths   November              100
#       Oct-2015    Number of Deaths    October              100
#       Oct-2016    Number of Deaths    October              100
#       Oct-2017    Number of Deaths    October              100
#       Sep-2015    Number of Deaths  September              100
#       Sep-2016    Number of Deaths  September              100
#       Sep-2017    Number of Deaths  September              100
#
#                  percent_pending_investigation predicted_value state_name  \
# state month-year
# AK    Apr-2015                               0             NaN         AK
#       Apr-2016                               0             NaN         AK
#       Apr-2017               0.069364161849711             NaN         AK
#       Apr-2018                               0             NaN         AK
#       Aug-2015                               0             NaN         AK
#       Aug-2016              0.0233863423760524             NaN         AK
#       Aug-2017              0.0472366556447803             NaN         AK
#       Aug-2018                               0             NaN         AK
#       Dec-2015                               0             NaN         AK
#       Dec-2016               0.068886337543054             NaN         AK
#       Dec-2017                               0             NaN         AK
#       Feb-2015                               0             NaN         AK
#       Feb-2016                               0             NaN         AK
#       Feb-2017              0.0690131124913734             NaN         AK
#       Feb-2018                               0             NaN         AK
#       Jan-2015                               0             NaN         AK
#       Jan-2016                               0             NaN         AK
#       Jan-2017              0.0685871056241426             NaN         AK
#       Jan-2018                               0             NaN         AK
#       Jul-2015                               0             NaN         AK
#       Jul-2016                               0             NaN         AK
#       Jul-2017              0.0708215297450425             NaN         AK
#       Jul-2018                               0             NaN         AK
#       Jul-2018                               0             NaN         AK
#       Jun-2015                               0             NaN         AK
#       Jun-2016                               0             NaN         AK
#       Jun-2017              0.0701590271281572             NaN         AK
#       Jun-2018                               0             NaN         AK
#       Jun-2018                               0             NaN         AK
#       Mar-2015                               0             NaN         AK
# ...                                        ...             ...        ...
# YC    Jan-2017              0.0384855037935711             NaN         YC
#       Jan-2018              0.0548075342090359             NaN         YC
#       Jul-2015              0.0368385183547918             NaN         YC
#       Jul-2016              0.0392508691263878             NaN         YC
#       Jul-2017               0.018450184501845             NaN         YC
#       Jul-2018               0.588726968782934             NaN         YC
#       Jul-2018               0.188970655037703             NaN         YC
#       Jun-2015              0.0332674145674312             NaN         YC
#       Jun-2016              0.0411715167961074             NaN         YC
#       Jun-2017              0.0184348787906719             NaN         YC
#       Jun-2018               0.150914578711953             NaN         YC
#       Jun-2018               0.389112133389094             NaN         YC
#       Mar-2015              0.0184675617278251             NaN         YC
#       Mar-2016               0.031747810334846             NaN         YC
#       Mar-2017              0.0387847446670976             NaN         YC
#       Mar-2018               0.141836233702471             NaN         YC
#       May-2015              0.0222102944714875             NaN         YC
#       May-2016              0.0504710632570659             NaN         YC
#       May-2017              0.0184522271838211             NaN         YC
#       May-2018               0.294995993881565             NaN         YC
#       May-2018               0.125644153904984             NaN         YC
#       Nov-2015               0.040500736377025             NaN         YC
#       Nov-2016              0.0371181470620987             NaN         YC
#       Nov-2017              0.0387161003668811             NaN         YC
#       Oct-2015              0.0403137139925236             NaN         YC
#       Oct-2016              0.0373517602016995             NaN         YC
#       Oct-2017              0.0276309245307348             NaN         YC
#       Sep-2015              0.0367316204154346             NaN         YC
#       Sep-2016              0.0373601330020735             NaN         YC
#       Sep-2017              0.0220868380850711             NaN         YC
#
#                   year
# state month-year
# AK    Apr-2015    2015
#       Apr-2016    2016
#       Apr-2017    2017
#       Apr-2018    2018
#       Aug-2015    2015
#       Aug-2016    2016
#       Aug-2017    2017
#       Aug-2018    2018
#       Dec-2015    2015
#       Dec-2016    2016
#       Dec-2017    2017
#       Feb-2015    2015
#       Feb-2016    2016
#       Feb-2017    2017
#       Feb-2018    2018
#       Jan-2015    2015
#       Jan-2016    2016
#       Jan-2017    2017
#       Jan-2018    2018
#       Jul-2015    2015
#       Jul-2016    2016
#       Jul-2017    2017
#       Jul-2018    2018
#       Jul-2018    2018
#       Jun-2015    2015
#       Jun-2016    2016
#       Jun-2017    2017
#       Jun-2018    2018
#       Jun-2018    2018
#       Mar-2015    2015
# ...                ...
# YC    Jan-2017    2017
#       Jan-2018    2018
#       Jul-2015    2015
#       Jul-2016    2016
#       Jul-2017    2017
#       Jul-2018    2018
#       Jul-2018    2018
#       Jun-2015    2015
#       Jun-2016    2016
#       Jun-2017    2017
#       Jun-2018    2018
#       Jun-2018    2018
#       Mar-2015    2015
#       Mar-2016    2016
#       Mar-2017    2017
#       Mar-2018    2018
#       May-2015    2015
#       May-2016    2016
#       May-2017    2017
#       May-2018    2018
#       May-2018    2018
#       Nov-2015    2015
#       Nov-2016    2016
#       Nov-2017    2017
#       Oct-2015    2015
#       Oct-2016    2016
#       Oct-2017    2017
#       Sep-2015    2015
#       Sep-2016    2016
#       Sep-2017    2017
#
# [2559 rows x 9 columns]

# %%
drug_index_dict = drug_df.to_dict()
drug_index_dict
# Out:
# {'data_value': {('AK', 'Apr-2015'): '4133',
#   ('AK', 'Apr-2016'): '4262',
#   ('AK', 'Apr-2017'): '4325',
#   ('AK', 'Apr-2018'): '4341',
#   ('AK', 'Aug-2015'): '4222',
#   ('AK', 'Aug-2016'): '4276',
#   ('AK', 'Aug-2017'): '4234',
#   ('AK', 'Aug-2018'): '4382',
#   ('AK', 'Dec-2015'): '4193',
#   ('AK', 'Dec-2016'): '4355',
#   ('AK', 'Dec-2017'): '4279',
#   ('AK', 'Feb-2015'): '4084',
#   ('AK', 'Feb-2016'): '4198',
#   ('AK', 'Feb-2017'): '4347',
#   ('AK', 'Feb-2018'): '4304',
#   ('AK', 'Jan-2015'): '4034',
#   ('AK', 'Jan-2016'): '4213',
#   ('AK', 'Jan-2017'): '4374',
#   ('AK', 'Jan-2018'): '4260',
#   ('AK', 'Jul-2015'): '4220',
#   ('AK', 'Jul-2016'): '4269',
#   ('AK', 'Jul-2017'): '4236',
#   ('AK', 'Jul-2018'): '4333',
#   ('AK', 'Jun-2015'): '4201',
#   ('AK', 'Jun-2016'): '4261',
#   ('AK', 'Jun-2017'): '4276',
#   ('AK', 'Jun-2018'): '4307',
#   ('AK', 'Mar-2015'): '4101',
#   ('AK', 'Mar-2016'): '4230',
#   ('AK', 'Mar-2017'): '4359',
#   ('AK', 'Mar-2018'): '4286',
#   ('AK', 'May-2015'): '4196',
#   ('AK', 'May-2016'): '4241',
#   ('AK', 'May-2017'): '4277',
#   ('AK', 'May-2018'): '4352',
#   ('AK', 'Nov-2015'): '4219',
#   ('AK', 'Nov-2016'): '4289',
#   ('AK', 'Nov-2017'): '4308',
#   ('AK', 'Oct-2015'): '4241',
#   ('AK', 'Oct-2016'): '4291',
#   ('AK', 'Oct-2017'): '4283',
#   ('AK', 'Sep-2015'): '4242',
#   ('AK', 'Sep-2016'): '4256',
#   ('AK', 'Sep-2017'): '4299',
#   ('AL', 'Apr-2015'): '50565',
#   ('AL', 'Apr-2016'): '50391',
#   ('AL', 'Apr-2017'): '51794',
#   ('AL', 'Apr-2018'): '53239',
#   ('AL', 'Aug-2015'): '50930',
#   ('AL', 'Aug-2016'): '50756',
#   ('AL', 'Aug-2017'): '52075',
#   ('AL', 'Aug-2018'): '53469',
#   ('AL', 'Dec-2015'): '50870',
#   ('AL', 'Dec-2016'): '51431',
#   ('AL', 'Dec-2017'): '52307',
#   ('AL', 'Feb-2015'): '50004',
#   ('AL', 'Feb-2016'): '50555',
#   ('AL', 'Feb-2017'): '51542',
#   ('AL', 'Feb-2018'): '53275',
#   ('AL', 'Jan-2015'): '49543',
#   ('AL', 'Jan-2016'): '50534',
#   ('AL', 'Jan-2017'): '51652',
#   ('AL', 'Jan-2018'): '53106',
#   ('AL', 'Jul-2015'): '50841',
#   ('AL', 'Jul-2016'): '50683',
#   ('AL', 'Jul-2017'): '52035',
#   ('AL', 'Jul-2018'): '53457',
#   ('AL', 'Jun-2015'): '50658',
#   ('AL', 'Jun-2016'): '50613',
#   ('AL', 'Jun-2017'): '52000',
#   ('AL', 'Jun-2018'): '53359',
#   ('AL', 'Mar-2015'): '50486',
#   ('AL', 'Mar-2016'): '50348',
#   ('AL', 'Mar-2017'): '51668',
#   ('AL', 'Mar-2018'): '53225',
#   ('AL', 'May-2015'): '50516',
#   ('AL', 'May-2016'): '50511',
#   ('AL', 'May-2017'): '51943',
#   ('AL', 'May-2018'): '53278',
#   ('AL', 'Nov-2015'): '51093',
#   ('AL', 'Nov-2016'): '51110',
#   ('AL', 'Nov-2017'): '52254',
#   ('AL', 'Oct-2015'): '51091',
#   ('AL', 'Oct-2016'): '50869',
#   ('AL', 'Oct-2017'): '52267',
#   ('AL', 'Sep-2015'): '51044',
#   ('AL', 'Sep-2016'): '50810',
#   ('AL', 'Sep-2017'): '52232',
#   ('AR', 'Apr-2015'): '30444',
#   ('AR', 'Apr-2016'): '30489',
#   ('AR', 'Apr-2017'): '31382',
#   ('AR', 'Apr-2018'): '32054',
#   ('AR', 'Aug-2015'): '30884',
#   ('AR', 'Aug-2016'): '30488',
#   ('AR', 'Aug-2017'): '31596',
#   ('AR', 'Aug-2018'): '31996',
#   ('AR', 'Dec-2015'): '30986',
#   ('AR', 'Dec-2016'): '31028',
#   ('AR', 'Dec-2017'): '31823',
#   ('AR', 'Feb-2015'): '30332',
#   ('AR', 'Feb-2016'): '30413',
#   ('AR', 'Feb-2017'): '31156',
#   ('AR', 'Feb-2018'): '32398',
#   ('AR', 'Jan-2015'): '30122',
#   ('AR', 'Jan-2016'): '30624',
#   ('AR', 'Jan-2017'): '31113',
#   ('AR', 'Jan-2018'): '32294',
#   ('AR', 'Jul-2015'): '30685',
#   ('AR', 'Jul-2016'): '30590',
#   ('AR', 'Jul-2017'): '31550',
#   ('AR', 'Jul-2018'): '32035',
#   ('AR', 'Jun-2015'): '30722',
#   ('AR', 'Jun-2016'): '30434',
#   ('AR', 'Jun-2017'): '31555',
#   ('AR', 'Jun-2018'): '32072',
#   ('AR', 'Mar-2015'): '30387',
#   ('AR', 'Mar-2016'): '30421',
#   ('AR', 'Mar-2017'): '31309',
#   ('AR', 'Mar-2018'): '32198',
#   ('AR', 'May-2015'): '30602',
#   ('AR', 'May-2016'): '30361',
#   ('AR', 'May-2017'): '31496',
#   ('AR', 'May-2018'): '32109',
#   ('AR', 'Nov-2015'): '31007',
#   ('AR', 'Nov-2016'): '30697',
#   ('AR', 'Nov-2017'): '31654',
#   ('AR', 'Oct-2015'): '31015',
#   ('AR', 'Oct-2016'): '30489',
#   ('AR', 'Oct-2017'): '31724',
#   ('AR', 'Sep-2015'): '30931',
#   ('AR', 'Sep-2016'): '30540',
#   ('AR', 'Sep-2017'): '31718',
#   ('AZ', 'Apr-2015'): '53025',
#   ('AZ', 'Apr-2016'): '56436',
#   ('AZ', 'Apr-2017'): '56454',
#   ('AZ', 'Apr-2018'): '60304',
#   ('AZ', 'Aug-2015'): '53907',
#   ('AZ', 'Aug-2016'): '56960',
#   ('AZ', 'Aug-2017'): '57310',
#   ('AZ', 'Aug-2018'): '60289',
#   ('AZ', 'Dec-2015'): '54853',
#   ('AZ', 'Dec-2016'): '57215',
#   ('AZ', 'Dec-2017'): '58440',
#   ('AZ', 'Feb-2015'): '52371',
#   ('AZ', 'Feb-2016'): '55755',
#   ('AZ', 'Feb-2017'): '56609',
#   ('AZ', 'Feb-2018'): '59898',
#   ('AZ', 'Jan-2015'): '52342',
#   ('AZ', 'Jan-2016'): '54917',
#   ('AZ', 'Jan-2017'): '57221',
#   ('AZ', 'Jan-2018'): '59585',
#   ('AZ', 'Jul-2015'): '53685',
#   ('AZ', 'Jul-2016'): '56865',
#   ('AZ', 'Jul-2017'): '57215',
#   ('AZ', 'Jul-2018'): '60170',
#   ('AZ', 'Jun-2015'): '53462',
#   ('AZ', 'Jun-2016'): '56648',
#   ('AZ', 'Jun-2017'): '57013',
#   ('AZ', 'Jun-2018'): '60112',
#   ('AZ', 'Mar-2015'): '52826',
#   ('AZ', 'Mar-2016'): '56319',
#   ('AZ', 'Mar-2017'): '56269',
#   ('AZ', 'Mar-2018'): '60190',
#   ('AZ', 'May-2015'): '53225',
#   ('AZ', 'May-2016'): '56522',
#   ('AZ', 'May-2017'): '56721',
#   ('AZ', 'May-2018'): '60185',
#   ('AZ', 'Nov-2015'): '54421',
#   ('AZ', 'Nov-2016'): '57252',
#   ('AZ', 'Nov-2017'): '57852',
#   ('AZ', 'Oct-2015'): '54122',
#   ('AZ', 'Oct-2016'): '57277',
#   ('AZ', 'Oct-2017'): '57694',
#   ('AZ', 'Sep-2015'): '54058',
#   ('AZ', 'Sep-2016'): '57051',
#   ('AZ', 'Sep-2017'): '57531',
#   ('CA', 'Apr-2015'): '252831',
#   ('CA', 'Apr-2016'): '261595',
#   ('CA', 'Apr-2017'): '265286',
#   ('CA', 'Apr-2018'): '272668',
#   ('CA', 'Aug-2015'): '256464',
#   ('CA', 'Aug-2016'): '261781',
#   ('CA', 'Aug-2017'): '267347',
#   ('CA', 'Aug-2018'): '272489',
#   ('CA', 'Dec-2015'): '260172',
#   ('CA', 'Dec-2016'): '263199',
#   ('CA', 'Dec-2017'): '269377',
#   ('CA', 'Feb-2015'): '249920',
#   ('CA', 'Feb-2016'): '260508',
#   ('CA', 'Feb-2017'): '264889',
#   ('CA', 'Feb-2018'): '271529',
#   ('CA', 'Jan-2015'): '248191',
#   ('CA', 'Jan-2016'): '259303',
#   ('CA', 'Jan-2017'): '265340',
#   ('CA', 'Jan-2018'): '271347',
#   ('CA', 'Jul-2015'): '255417',
#   ('CA', 'Jul-2016'): '261603',
#   ('CA', 'Jul-2017'): '267372',
#   ('CA', 'Jul-2018'): '272068',
#   ('CA', 'Jun-2015'): '254838',
#   ('CA', 'Jun-2016'): '261467',
#   ('CA', 'Jun-2017'): '266897',
#   ('CA', 'Jun-2018'): '271928',
#   ('CA', 'Mar-2015'): '251540',
#   ('CA', 'Mar-2016'): '261416',
#   ('CA', 'Mar-2017'): '264767',
#   ('CA', 'Mar-2018'): '272915',
#   ('CA', 'May-2015'): '253858',
#   ('CA', 'May-2016'): '261557',
#   ('CA', 'May-2017'): '265953',
#   ('CA', 'May-2018'): '272212',
#   ('CA', 'Nov-2015'): '258808',
#   ('CA', 'Nov-2016'): '262360',
#   ('CA', 'Nov-2017'): '268369',
#   ('CA', 'Oct-2015'): '257750',
#   ('CA', 'Oct-2016'): '262751',
#   ('CA', 'Oct-2017'): '268366',
#   ('CA', 'Sep-2015'): '257163',
#   ('CA', 'Sep-2016'): '262041',
#   ('CA', 'Sep-2017'): '268090',
#   ('CO', 'Apr-2015'): '36601',
#   ('CO', 'Apr-2016'): '37351',
#   ('CO', 'Apr-2017'): '38521',
#   ('CO', 'Apr-2018'): '38931',
#   ('CO', 'Aug-2015'): '37125',
#   ('CO', 'Aug-2016'): '37650',
#   ('CO', 'Aug-2017'): '38380',
#   ('CO', 'Aug-2018'): '39281',
#   ('CO', 'Dec-2015'): '36993',
#   ('CO', 'Dec-2016'): '38151',
#   ('CO', 'Dec-2017'): '38759',
#   ('CO', 'Feb-2015'): '36330',
#   ('CO', 'Feb-2016'): '36987',
#   ('CO', 'Feb-2017'): '38358',
#   ('CO', 'Feb-2018'): '38953',
#   ('CO', 'Jan-2015'): '36264',
#   ('CO', 'Jan-2016'): '36752',
#   ('CO', 'Jan-2017'): '38236',
#   ('CO', 'Jan-2018'): '38985',
#   ('CO', 'Jul-2015'): '36960',
#   ('CO', 'Jul-2016'): '37620',
#   ('CO', 'Jul-2017'): '38367',
#   ('CO', 'Jul-2018'): '39079',
#   ('CO', 'Jun-2015'): '36816',
#   ('CO', 'Jun-2016'): '37504',
#   ('CO', 'Jun-2017'): '38470',
#   ('CO', 'Jun-2018'): '38973',
#   ('CO', 'Mar-2015'): '36300',
#   ('CO', 'Mar-2016'): '37387',
#   ('CO', 'Mar-2017'): '38364',
#   ('CO', 'Mar-2018'): '38963',
#   ('CO', 'May-2015'): '36667',
#   ('CO', 'May-2016'): '37535',
#   ('CO', 'May-2017'): '38410',
#   ('CO', 'May-2018'): '39007',
#   ('CO', 'Nov-2015'): '37144',
#   ('CO', 'Nov-2016'): '38075',
#   ('CO', 'Nov-2017'): '38704',
#   ('CO', 'Oct-2015'): '37144',
#   ('CO', 'Oct-2016'): '38048',
#   ('CO', 'Oct-2017'): '38590',
#   ('CO', 'Sep-2015'): '37101',
#   ('CO', 'Sep-2016'): '37834',
#   ('CO', 'Sep-2017'): '38542',
#   ('CT', 'Apr-2015'): '30431',
#   ('CT', 'Apr-2016'): '30198',
#   ('CT', 'Apr-2017'): '31103',
#   ('CT', 'Apr-2018'): '31562',
#   ('CT', 'Aug-2015'): '30549',
#   ('CT', 'Aug-2016'): '30156',
#   ('CT', 'Aug-2017'): '31374',
#   ('CT', 'Aug-2018'): '31591',
#   ('CT', 'Dec-2015'): '30600',
#   ('CT', 'Dec-2016'): '30641',
#   ('CT', 'Dec-2017'): '31542',
#   ('CT', 'Feb-2015'): '30349',
#   ('CT', 'Feb-2016'): '30231',
#   ('CT', 'Feb-2017'): '31023',
#   ('CT', 'Feb-2018'): '31569',
#   ('CT', 'Jan-2015'): '30221',
#   ('CT', 'Jan-2016'): '30368',
#   ('CT', 'Jan-2017'): '30834',
#   ('CT', 'Jan-2018'): '31745',
#   ('CT', 'Jul-2015'): '30612',
#   ('CT', 'Jul-2016'): '30094',
#   ('CT', 'Jul-2017'): '31345',
#   ('CT', 'Jul-2018'): '31528',
#   ('CT', 'Jun-2015'): '30508',
#   ('CT', 'Jun-2016'): '30188',
#   ('CT', 'Jun-2017'): '31248',
#   ('CT', 'Jun-2018'): '31447',
#   ('CT', 'Mar-2015'): '30497',
#   ('CT', 'Mar-2016'): '30162',
#   ('CT', 'Mar-2017'): '31060',
#   ('CT', 'Mar-2018'): '31528',
#   ('CT', 'May-2015'): '30437',
#   ('CT', 'May-2016'): '30198',
#   ('CT', 'May-2017'): '31116',
#   ('CT', 'May-2018'): '31589',
#   ('CT', 'Nov-2015'): '30751',
#   ('CT', 'Nov-2016'): '30294',
#   ('CT', 'Nov-2017'): '31424',
#   ('CT', 'Oct-2015'): '30615',
#   ('CT', 'Oct-2016'): '30155',
#   ('CT', 'Oct-2017'): '31511',
#   ('CT', 'Sep-2015'): '30556',
#   ('CT', 'Sep-2016'): '30088',
#   ('CT', 'Sep-2017'): '31543',
#   ('DC', 'Apr-2015'): '5740',
#   ('DC', 'Apr-2016'): '5662',
#   ('DC', 'Apr-2017'): '6241',
#   ('DC', 'Apr-2018'): '6202',
#   ('DC', 'Aug-2015'): '5703',
#   ('DC', 'Aug-2016'): '5789',
#   ('DC', 'Aug-2017'): '6296',
#   ('DC', 'Aug-2018'): '6211',
#   ('DC', 'Dec-2015'): '5706',
#   ('DC', 'Dec-2016'): '6055',
#   ('DC', 'Dec-2017'): '6238',
#   ('DC', 'Feb-2015'): '5632',
#   ('DC', 'Feb-2016'): '5610',
#   ('DC', 'Feb-2017'): '6177',
#   ('DC', 'Feb-2018'): '6278',
#   ('DC', 'Jan-2015'): '5589',
#   ('DC', 'Jan-2016'): '5616',
#   ('DC', 'Jan-2017'): '6128',
#   ('DC', 'Jan-2018'): '6296',
#   ('DC', 'Jul-2015'): '5668',
#   ('DC', 'Jul-2016'): '5770',
#   ('DC', 'Jul-2017'): '6314',
#   ('DC', 'Jul-2018'): '6188',
#   ('DC', 'Jun-2015'): '5678',
#   ('DC', 'Jun-2016'): '5731',
#   ('DC', 'Jun-2017'): '6328',
#   ('DC', 'Jun-2018'): '6172',
#   ('DC', 'Mar-2015'): '5704',
#   ('DC', 'Mar-2016'): '5620',
#   ('DC', 'Mar-2017'): '6227',
#   ('DC', 'Mar-2018'): '6238',
#   ('DC', 'May-2015'): '5706',
#   ('DC', 'May-2016'): '5719',
#   ('DC', 'May-2017'): '6287',
#   ('DC', 'May-2018'): '6183',
#   ('DC', 'Nov-2015'): '5754',
#   ('DC', 'Nov-2016'): '5933',
#   ('DC', 'Nov-2017'): '6257',
#   ('DC', 'Oct-2015'): '5719',
#   ('DC', 'Oct-2016'): '5876',
#   ('DC', 'Oct-2017'): '6301',
#   ('DC', 'Sep-2015'): '5683',
#   ('DC', 'Sep-2016'): '5869',
#   ('DC', 'Sep-2017'): '6302',
#   ('DE', 'Apr-2015'): '8580',
#   ('DE', 'Apr-2016'): '8530',
#   ('DE', 'Apr-2017'): '9150',
#   ('DE', 'Apr-2018'): '9268',
#   ('DE', 'Aug-2015'): '8648',
#   ('DE', 'Aug-2016'): '8666',
#   ('DE', 'Aug-2017'): '9089',
#   ('DE', 'Aug-2018'): '9520',
#   ('DE', 'Dec-2015'): '8591',
#   ('DE', 'Dec-2016'): '8980',
#   ('DE', 'Dec-2017'): '9132',
#   ('DE', 'Feb-2015'): '8561',
#   ('DE', 'Feb-2016'): '8473',
#   ('DE', 'Feb-2017'): '9085',
#   ('DE', 'Feb-2018'): '9195',
#   ('DE', 'Jan-2015'): '8485',
#   ('DE', 'Jan-2016'): '8485',
#   ('DE', 'Jan-2017'): '9058',
#   ('DE', 'Jan-2018'): '9132',
#   ('DE', 'Jul-2015'): '8642',
#   ('DE', 'Jul-2016'): '8609',
#   ('DE', 'Jul-2017'): '9108',
#   ('DE', 'Jul-2018'): '9486',
#   ('DE', 'Jun-2015'): '8577',
#   ('DE', 'Jun-2016'): '8571',
#   ('DE', 'Jun-2017'): '9098',
#   ('DE', 'Jun-2018'): '9430',
#   ('DE', 'Mar-2015'): '8551',
#   ('DE', 'Mar-2016'): '8555',
#   ('DE', 'Mar-2017'): '9099',
#   ('DE', 'Mar-2018'): '9225',
#   ('DE', 'May-2015'): '8583',
#   ('DE', 'May-2016'): '8553',
#   ('DE', 'May-2017'): '9119',
#   ('DE', 'May-2018'): '9339',
#   ('DE', 'Nov-2015'): '8666',
#   ('DE', 'Nov-2016'): '8889',
#   ('DE', 'Nov-2017'): '9047',
#   ('DE', 'Oct-2015'): '8661',
#   ('DE', 'Oct-2016'): '8809',
#   ('DE', 'Oct-2017'): '9016',
#   ('DE', 'Sep-2015'): '8686',
#   ('DE', 'Sep-2016'): '8740',
#   ('DE', 'Sep-2017'): '9045',
#   ('FL', 'Apr-2015'): '192268',
#   ('FL', 'Apr-2016'): '195883',
#   ('FL', 'Apr-2017'): '201341',
#   ('FL', 'Apr-2018'): '208895',
#   ('FL', 'Aug-2015'): '194364',
#   ('FL', 'Aug-2016'): '197300',
#   ('FL', 'Aug-2017'): '202940',
#   ('FL', 'Aug-2018'): '209175',
#   ('FL', 'Dec-2015'): '194297',
#   ('FL', 'Dec-2016'): '199964',
#   ('FL', 'Dec-2017'): '206171',
#   ('FL', 'Feb-2015'): '190591',
#   ('FL', 'Feb-2016'): '194386',
#   ('FL', 'Feb-2017'): '200708',
#   ('FL', 'Feb-2018'): '208896',
#   ('FL', 'Jan-2015'): '189170',
#   ('FL', 'Jan-2016'): '193810',
#   ('FL', 'Jan-2017'): '200883',
#   ('FL', 'Jan-2018'): '208171',
#   ('FL', 'Jul-2015'): '193875',
#   ('FL', 'Jul-2016'): '196733',
#   ('FL', 'Jul-2017'): '202400',
#   ('FL', 'Jul-2018'): '209556',
#   ('FL', 'Jun-2015'): '193387',
#   ('FL', 'Jun-2016'): '196273',
#   ('FL', 'Jun-2017'): '202314',
#   ('FL', 'Jun-2018'): '209229',
#   ('FL', 'Mar-2015'): '191745',
#   ('FL', 'Mar-2016'): '195215',
#   ('FL', 'Mar-2017'): '200881',
#   ('FL', 'Mar-2018'): '208926',
#   ('FL', 'May-2015'): '193067',
#   ('FL', 'May-2016'): '196050',
#   ('FL', 'May-2017'): '201706',
#   ('FL', 'May-2018'): '208958',
#   ('FL', 'Nov-2015'): '195311',
#   ('FL', 'Nov-2016'): '199256',
#   ('FL', 'Nov-2017'): '205023',
#   ('FL', 'Oct-2015'): '195599',
#   ('FL', 'Oct-2016'): '198220',
#   ('FL', 'Oct-2017'): '204665',
#   ('FL', 'Sep-2015'): '195097',
#   ('FL', 'Sep-2016'): '197602',
#   ('FL', 'Sep-2017'): '203978',
#   ('GA', 'Apr-2015'): '79111',
#   ('GA', 'Apr-2016'): '80405',
#   ('GA', 'Apr-2017'): '82588',
#   ('GA', 'Apr-2018'): '85196',
#   ('GA', 'Aug-2015'): '80081',
#   ('GA', 'Aug-2016'): '81003',
#   ('GA', 'Aug-2017'): '83122',
#   ('GA', 'Aug-2018'): '85516',
#   ('GA', 'Dec-2015'): '80541',
#   ('GA', 'Dec-2016'): '81783',
#   ('GA', 'Dec-2017'): '83679',
#   ('GA', 'Feb-2015'): '78215',
#   ('GA', 'Feb-2016'): '80280',
#   ('GA', 'Feb-2017'): '82143',
#   ('GA', 'Feb-2018'): '85223',
#   ('GA', 'Jan-2015'): '77687',
#   ('GA', 'Jan-2016'): '80247',
#   ('GA', 'Jan-2017'): '82150',
#   ('GA', 'Jan-2018'): '84833',
#   ('GA', 'Jul-2015'): '79994',
#   ('GA', 'Jul-2016'): '80602',
#   ('GA', 'Jul-2017'): '83087',
#   ('GA', 'Jul-2018'): '85311',
#   ('GA', 'Jun-2015'): '79559',
#   ('GA', 'Jun-2016'): '80535',
#   ('GA', 'Jun-2017'): '82946',
#   ('GA', 'Jun-2018'): '85412',
#   ('GA', 'Mar-2015'): '78805',
#   ('GA', 'Mar-2016'): '80292',
#   ('GA', 'Mar-2017'): '82436',
#   ('GA', 'Mar-2018'): '85080',
#   ('GA', 'May-2015'): '79186',
#   ('GA', 'May-2016'): '80430',
#   ('GA', 'May-2017'): '82813',
#   ('GA', 'May-2018'): '85434',
#   ('GA', 'Nov-2015'): '80919',
#   ('GA', 'Nov-2016'): '81392',
#   ('GA', 'Nov-2017'): '83665',
#   ('GA', 'Oct-2015'): '80715',
#   ('GA', 'Oct-2016'): '81277',
#   ('GA', 'Oct-2017'): '83588',
#   ('GA', 'Sep-2015'): '80392',
#   ('GA', 'Sep-2016'): '81280',
#   ('GA', 'Sep-2017'): '83199',
#   ('HI', 'Apr-2015'): '11031',
#   ('HI', 'Apr-2016'): '11057',
#   ('HI', 'Apr-2017'): '11205',
#   ('HI', 'Apr-2018'): '11672',
#   ('HI', 'Aug-2015'): '11116',
#   ('HI', 'Aug-2016'): '10892',
#   ('HI', 'Aug-2017'): '11409',
#   ('HI', 'Aug-2018'): '11634',
#   ('HI', 'Dec-2015'): '11208',
#   ('HI', 'Dec-2016'): '11041',
#   ('HI', 'Dec-2017'): '11508',
#   ('HI', 'Feb-2015'): '11076',
#   ('HI', 'Feb-2016'): '11065',
#   ('HI', 'Feb-2017'): '11111',
#   ('HI', 'Feb-2018'): '11575',
#   ('HI', 'Jan-2015'): '11026',
#   ('HI', 'Jan-2016'): '11070',
#   ('HI', 'Jan-2017'): '11142',
#   ('HI', 'Jan-2018'): '11517',
#   ('HI', 'Jul-2015'): '11111',
#   ('HI', 'Jul-2016'): '10896',
#   ('HI', 'Jul-2017'): '11384',
#   ('HI', 'Jul-2018'): '11653',
#   ('HI', 'Jun-2015'): '11100',
#   ('HI', 'Jun-2016'): '10901',
#   ('HI', 'Jun-2017'): '11380',
#   ('HI', 'Jun-2018'): '11644',
#   ('HI', 'Mar-2015'): '11073',
#   ('HI', 'Mar-2016'): '11067',
#   ('HI', 'Mar-2017'): '11136',
#   ('HI', 'Mar-2018'): '11655',
#   ('HI', 'May-2015'): '11063',
#   ('HI', 'May-2016'): '10969',
#   ('HI', 'May-2017'): '11306',
#   ('HI', 'May-2018'): '11614',
#   ('HI', 'Nov-2015'): '11203',
#   ('HI', 'Nov-2016'): '10939',
#   ('HI', 'Nov-2017'): '11450',
#   ('HI', 'Oct-2015'): '11187',
#   ('HI', 'Oct-2016'): '10870',
#   ('HI', 'Oct-2017'): '11391',
#   ('HI', 'Sep-2015'): '11154',
#   ('HI', 'Sep-2016'): '10824',
#   ('HI', 'Sep-2017'): '11426',
#   ('IA', 'Apr-2015'): '29412',
#   ('IA', 'Apr-2016'): '28908',
#   ('IA', 'Apr-2017'): '29999',
#   ('IA', 'Apr-2018'): '30146',
#   ('IA', 'Aug-2015'): '29667',
#   ('IA', 'Aug-2016'): '28760',
#   ('IA', 'Aug-2017'): '30109',
#   ('IA', 'Aug-2018'): '30288',
#   ('IA', 'Dec-2015'): '29291',
#   ('IA', 'Dec-2016'): '29318',
#   ('IA', 'Dec-2017'): '30242',
#   ('IA', 'Feb-2015'): '29203',
#   ('IA', 'Feb-2016'): '29156',
#   ('IA', 'Feb-2017'): '29703',
#   ('IA', 'Feb-2018'): '30193',
#   ('IA', 'Jan-2015'): '29177',
#   ('IA', 'Jan-2016'): '29031',
#   ('IA', 'Jan-2017'): '29622',
#   ('IA', 'Jan-2018'): '30144',
#   ('IA', 'Jul-2015'): '29649',
#   ('IA', 'Jul-2016'): '28746',
#   ('IA', 'Jul-2017'): '30210',
#   ('IA', 'Jul-2018'): '30184',
#   ('IA', 'Jun-2015'): '29533',
#   ('IA', 'Jun-2016'): '28863',
#   ('IA', 'Jun-2017'): '30213',
#   ('IA', 'Jun-2018'): '30120',
#   ('IA', 'Mar-2015'): '29380',
#   ('IA', 'Mar-2016'): '28911',
#   ('IA', 'Mar-2017'): '29945',
#   ('IA', 'Mar-2018'): '30109',
#   ('IA', 'May-2015'): '29462',
#   ('IA', 'May-2016'): '28909',
#   ('IA', 'May-2017'): '30121',
#   ('IA', 'May-2018'): '30068',
#   ('IA', 'Nov-2015'): '29599',
#   ('IA', 'Nov-2016'): '29018',
#   ('IA', 'Nov-2017'): '30220',
#   ('IA', 'Oct-2015'): '29692',
#   ('IA', 'Oct-2016'): '28956',
#   ('IA', 'Oct-2017'): '30135',
#   ('IA', 'Sep-2015'): '29678',
#   ('IA', 'Sep-2016'): '28822',
#   ('IA', 'Sep-2017'): '30122',
#   ('ID', 'Apr-2015'): '12753',
#   ('ID', 'Apr-2016'): '13093',
#   ('ID', 'Apr-2017'): '13619',
#   ('ID', 'Apr-2018'): '13984',
#   ('ID', 'Aug-2015'): '12836',
#   ('ID', 'Aug-2016'): '13283',
#   ('ID', 'Aug-2017'): '13656',
#   ('ID', 'Aug-2018'): '14119',
#   ('ID', 'Dec-2015'): '12987',
#   ('ID', 'Dec-2016'): '13297',
#   ('ID', 'Dec-2017'): '13908',
#   ('ID', 'Feb-2015'): '12669',
#   ('ID', 'Feb-2016'): '12987',
#   ('ID', 'Feb-2017'): '13530',
#   ('ID', 'Feb-2018'): '13928',
#   ('ID', 'Jan-2015'): '12667',
#   ('ID', 'Jan-2016'): '12912',
#   ('ID', 'Jan-2017'): '13479',
#   ('ID', 'Jan-2018'): '13900',
#   ('ID', 'Jul-2015'): '12917',
#   ('ID', 'Jul-2016'): '13228',
#   ('ID', 'Jul-2017'): '13621',
#   ('ID', 'Jul-2018'): '14108',
#   ('ID', 'Jun-2015'): '12831',
#   ('ID', 'Jun-2016'): '13221',
#   ('ID', 'Jun-2017'): '13580',
#   ('ID', 'Jun-2018'): '14048',
#   ('ID', 'Mar-2015'): '12693',
#   ('ID', 'Mar-2016'): '13036',
#   ('ID', 'Mar-2017'): '13601',
#   ('ID', 'Mar-2018'): '13964',
#   ('ID', 'May-2015'): '12849',
#   ('ID', 'May-2016'): '13131',
#   ('ID', 'May-2017'): '13588',
#   ('ID', 'May-2018'): '14021',
#   ('ID', 'Nov-2015'): '12905',
#   ('ID', 'Nov-2016'): '13190',
#   ('ID', 'Nov-2017'): '13936',
#   ('ID', 'Oct-2015'): '12892',
#   ('ID', 'Oct-2016'): '13205',
#   ('ID', 'Oct-2017'): '13864',
#   ('ID', 'Sep-2015'): '12782',
#   ('ID', 'Sep-2016'): '13227',
#   ('ID', 'Sep-2017'): '13769',
#   ('IL', 'Apr-2015'): '104256',
#   ('IL', 'Apr-2016'): '103291',
#   ('IL', 'Apr-2017'): '105559',
#   ('IL', 'Apr-2018'): '107683',
#   ('IL', 'Aug-2015'): '105266',
#   ('IL', 'Aug-2016'): '103292',
#   ('IL', 'Aug-2017'): '105639',
#   ('IL', 'Aug-2018'): '107609',
#   ('IL', 'Dec-2015'): '103953',
#   ('IL', 'Dec-2016'): '104091',
#   ('IL', 'Dec-2017'): '106635',
#   ('IL', 'Feb-2015'): '103174',
#   ('IL', 'Feb-2016'): '103656',
#   ('IL', 'Feb-2017'): '104986',
#   ('IL', 'Feb-2018'): '107652',
#   ('IL', 'Jan-2015'): '103054',
#   ('IL', 'Jan-2016'): '103132',
#   ('IL', 'Jan-2017'): '104762',
#   ('IL', 'Jan-2018'): '107753',
#   ('IL', 'Jul-2015'): '104977',
#   ('IL', 'Jul-2016'): '103249',
#   ('IL', 'Jul-2017'): '105607',
#   ('IL', 'Jul-2018'): '107753',
#   ('IL', 'Jun-2015'): '104648',
#   ('IL', 'Jun-2016'): '103275',
#   ('IL', 'Jun-2017'): '105673',
#   ('IL', 'Jun-2018'): '107631',
#   ('IL', 'Mar-2015'): '103679',
#   ('IL', 'Mar-2016'): '103543',
#   ('IL', 'Mar-2017'): '105376',
#   ('IL', 'Mar-2018'): '107327',
#   ('IL', 'May-2015'): '104525',
#   ('IL', 'May-2016'): '103228',
#   ('IL', 'May-2017'): '105625',
#   ('IL', 'May-2018'): '107678',
#   ('IL', 'Nov-2015'): '105252',
#   ('IL', 'Nov-2016'): '103309',
#   ('IL', 'Nov-2017'): '106309',
#   ('IL', 'Oct-2015'): '105465',
#   ('IL', 'Oct-2016'): '103256',
#   ('IL', 'Oct-2017'): '105958',
#   ('IL', 'Sep-2015'): '105207',
#   ('IL', 'Sep-2016'): '103368',
#   ('IL', 'Sep-2017'): '105968',
#   ('IN', 'Apr-2015'): '63354',
#   ('IN', 'Apr-2016'): '62811',
#   ('IN', 'Apr-2017'): '65321',
#   ('IN', 'Apr-2018'): '66176',
#   ('IN', 'Aug-2015'): '63694',
#   ('IN', 'Aug-2016'): '62933',
#   ('IN', 'Aug-2017'): '65909',
#   ('IN', 'Aug-2018'): '66213',
#   ('IN', 'Dec-2015'): '63255',
#   ('IN', 'Dec-2016'): '64051',
#   ('IN', 'Dec-2017'): '66053',
#   ('IN', 'Feb-2015'): '62377',
#   ('IN', 'Feb-2016'): '62863',
#   ('IN', 'Feb-2017'): '64783',
#   ('IN', 'Feb-2018'): '66497',
#   ('IN', 'Jan-2015'): '62174',
#   ('IN', 'Jan-2016'): '62610',
#   ('IN', 'Jan-2017'): '64506',
#   ('IN', 'Jan-2018'): '66622',
#   ('IN', 'Jul-2015'): '63570',
#   ('IN', 'Jul-2016'): '62795',
#   ('IN', 'Jul-2017'): '65911',
#   ('IN', 'Jul-2018'): '66090',
#   ('IN', 'Jun-2015'): '63517',
#   ('IN', 'Jun-2016'): '62648',
#   ('IN', 'Jun-2017'): '65867',
#   ('IN', 'Jun-2018'): '66085',
#   ('IN', 'Mar-2015'): '62886',
#   ('IN', 'Mar-2016'): '62968',
#   ('IN', 'Mar-2017'): '65084',
#   ('IN', 'Mar-2018'): '66195',
#   ('IN', 'May-2015'): '63491',
#   ('IN', 'May-2016'): '62632',
#   ('IN', 'May-2017'): '65558',
#   ('IN', 'May-2018'): '66214',
#   ('IN', 'Nov-2015'): '63655',
#   ('IN', 'Nov-2016'): '63580',
#   ('IN', 'Nov-2017'): '66004',
#   ('IN', 'Oct-2015'): '63829',
#   ('IN', 'Oct-2016'): '63185',
#   ('IN', 'Oct-2017'): '66020',
#   ('IN', 'Sep-2015'): '63837',
#   ('IN', 'Sep-2016'): '62891',
#   ('IN', 'Sep-2017'): '66057',
#   ('KS', 'Apr-2015'): '25392',
#   ('KS', 'Apr-2016'): '25463',
#   ('KS', 'Apr-2017'): '26134',
#   ('KS', 'Apr-2018'): '26332',
#   ('KS', 'Aug-2015'): '25885',
#   ('KS', 'Aug-2016'): '25308',
#   ('KS', 'Aug-2017'): '26011',
#   ('KS', 'Aug-2018'): '26467',
#   ('KS', 'Dec-2015'): '25863',
#   ('KS', 'Dec-2016'): '25489',
#   ('KS', 'Dec-2017'): '26148',
#   ('KS', 'Feb-2015'): '25320',
#   ('KS', 'Feb-2016'): '25507',
#   ('KS', 'Feb-2017'): '25933',
#   ('KS', 'Feb-2018'): '26298',
#   ('KS', 'Jan-2015'): '25208',
#   ('KS', 'Jan-2016'): '25598',
#   ('KS', 'Jan-2017'): '25718',
#   ('KS', 'Jan-2018'): '26281',
#   ('KS', 'Jul-2015'): '25803',
#   ('KS', 'Jul-2016'): '25292',
#   ('KS', 'Jul-2017'): '26133',
#   ('KS', 'Jul-2018'): '26422',
#   ('KS', 'Jun-2015'): '25657',
#   ('KS', 'Jun-2016'): '25353',
#   ('KS', 'Jun-2017'): '26079',
#   ('KS', 'Jun-2018'): '26517',
#   ('KS', 'Mar-2015'): '25392',
#   ('KS', 'Mar-2016'): '25415',
#   ('KS', 'Mar-2017'): '26130',
#   ('KS', 'Mar-2018'): '26276',
#   ('KS', 'May-2015'): '25456',
#   ('KS', 'May-2016'): '25400',
#   ('KS', 'May-2017'): '26151',
#   ('KS', 'May-2018'): '26365',
#   ('KS', 'Nov-2015'): '25935',
#   ('KS', 'Nov-2016'): '25296',
#   ('KS', 'Nov-2017'): '26132',
#   ('KS', 'Oct-2015'): '26017',
#   ('KS', 'Oct-2016'): '25174',
#   ('KS', 'Oct-2017'): '26140',
#   ('KS', 'Sep-2015'): '25920',
#   ('KS', 'Sep-2016'): '25223',
#   ('KS', 'Sep-2017'): '26084',
#   ('KY', 'Apr-2015'): '45635',
#   ('KY', 'Apr-2016'): '46307',
#   ('KY', 'Apr-2017'): '48046',
#   ('KY', 'Apr-2018'): '48173',
#   ('KY', 'Aug-2015'): '45990',
#   ('KY', 'Aug-2016'): '46769',
#   ('KY', 'Aug-2017'): '48144',
#   ('KY', 'Aug-2018'): '48150',
#   ('KY', 'Dec-2015'): '46195',
#   ('KY', 'Dec-2016'): '47606',
#   ('KY', 'Dec-2017'): '48014',
#   ('KY', 'Feb-2015'): '45331',
#   ('KY', 'Feb-2016'): '45854',
#   ('KY', 'Feb-2017'): '47924',
#   ('KY', 'Feb-2018'): '48342',
#   ('KY', 'Jan-2015'): '44911',
#   ('KY', 'Jan-2016'): '45819',
#   ('KY', 'Jan-2017'): '47839',
#   ('KY', 'Jan-2018'): '48413',
#   ('KY', 'Jul-2015'): '45917',
#   ('KY', 'Jul-2016'): '46593',
#   ('KY', 'Jul-2017'): '48228',
#   ('KY', 'Jul-2018'): '48044',
#   ('KY', 'Jun-2015'): '45839',
#   ('KY', 'Jun-2016'): '46456',
#   ('KY', 'Jun-2017'): '48254',
#   ('KY', 'Jun-2018'): '48052',
#   ('KY', 'Mar-2015'): '45453',
#   ('KY', 'Mar-2016'): '46039',
#   ('KY', 'Mar-2017'): '48020',
#   ('KY', 'Mar-2018'): '48244',
#   ('KY', 'May-2015'): '45852',
#   ('KY', 'May-2016'): '46269',
#   ('KY', 'May-2017'): '48136',
#   ('KY', 'May-2018'): '48170',
#   ('KY', 'Nov-2015'): '46396',
#   ('KY', 'Nov-2016'): '47283',
#   ('KY', 'Nov-2017'): '47845',
#   ('KY', 'Oct-2015'): '46372',
#   ('KY', 'Oct-2016'): '47070',
#   ('KY', 'Oct-2017'): '47967',
#   ('KY', 'Sep-2015'): '46169',
#   ('KY', 'Sep-2016'): '47052',
#   ('KY', 'Sep-2017'): '48012',
#   ('LA', 'Apr-2015'): '44230',
#   ('LA', 'Apr-2016'): '43610',
#   ('LA', 'Apr-2017'): '44836',
#   ('LA', 'Apr-2018'): '46529',
#   ('LA', 'Aug-2015'): '44240',
#   ('LA', 'Aug-2016'): '43939',
#   ('LA', 'Aug-2017'): '45031',
#   ('LA', 'Aug-2018'): '46688',
#   ('LA', 'Dec-2015'): '43914',
#   ('LA', 'Dec-2016'): '44411',
#   ('LA', 'Dec-2017'): '45953',
#   ('LA', 'Feb-2015'): '44150',
#   ('LA', 'Feb-2016'): '43428',
#   ('LA', 'Feb-2017'): '44597',
#   ('LA', 'Feb-2018'): '46891',
#   ('LA', 'Jan-2015'): '44100',
#   ('LA', 'Jan-2016'): '43495',
#   ('LA', 'Jan-2017'): '44579',
#   ('LA', 'Jan-2018'): '46783',
#   ('LA', 'Jul-2015'): '44204',
#   ('LA', 'Jul-2016'): '43742',
#   ('LA', 'Jul-2017'): '44995',
#   ('LA', 'Jul-2018'): '46672',
#   ('LA', 'Jun-2015'): '44191',
#   ('LA', 'Jun-2016'): '43768',
#   ('LA', 'Jun-2017'): '44976',
#   ('LA', 'Jun-2018'): '46649',
#   ('LA', 'Mar-2015'): '44301',
#   ('LA', 'Mar-2016'): '43445',
#   ('LA', 'Mar-2017'): '44769',
#   ('LA', 'Mar-2018'): '46594',
#   ('LA', 'May-2015'): '44154',
#   ('LA', 'May-2016'): '43743',
#   ('LA', 'May-2017'): '44913',
#   ('LA', 'May-2018'): '46598',
#   ('LA', 'Nov-2015'): '44169',
#   ('LA', 'Nov-2016'): '44340',
#   ('LA', 'Nov-2017'): '45331',
#   ('LA', 'Oct-2015'): '44348',
#   ('LA', 'Oct-2016'): '44225',
#   ('LA', 'Oct-2017'): '45068',
#   ('LA', 'Sep-2015'): '44371',
#   ('LA', 'Sep-2016'): '44033',
#   ('LA', 'Sep-2017'): '45019',
#   ('MA', 'Apr-2015'): '58197',
#   ('MA', 'Apr-2016'): '57077',
#   ('MA', 'Apr-2017'): '59087',
#   ('MA', 'Apr-2018'): '59637',
#   ('MA', 'Aug-2015'): '58790',
#   ('MA', 'Aug-2016'): '56981',
#   ('MA', 'Aug-2017'): '59589',
#   ('MA', 'Aug-2018'): '59738',
#   ('MA', 'Dec-2015'): '58761',
#   ('MA', 'Dec-2016'): '57861',
#   ('MA', 'Dec-2017'): '59727',
#   ('MA', 'Feb-2015'): '57676',
#   ('MA', 'Feb-2016'): '57469',
#   ('MA', 'Feb-2017'): '58797',
#   ('MA', 'Feb-2018'): '59852',
#   ('MA', 'Jan-2015'): '57044',
#   ('MA', 'Jan-2016'): '57874',
#   ('MA', 'Jan-2017'): '58454',
#   ('MA', 'Jan-2018'): '60029',
#   ('MA', 'Jul-2015'): '58729',
#   ('MA', 'Jul-2016'): '56793',
#   ('MA', 'Jul-2017'): '59435',
#   ('MA', 'Jul-2018'): '59909',
#   ('MA', 'Jun-2015'): '58523',
#   ('MA', 'Jun-2016'): '56937',
#   ('MA', 'Jun-2017'): '59166',
#   ('MA', 'Jun-2018'): '59888',
#   ('MA', 'Mar-2015'): '58056',
#   ('MA', 'Mar-2016'): '57250',
#   ('MA', 'Mar-2017'): '58965',
#   ('MA', 'Mar-2018'): '59769',
#   ('MA', 'May-2015'): '58356',
#   ('MA', 'May-2016'): '56934',
#   ('MA', 'May-2017'): '59072',
#   ('MA', 'May-2018'): '59855',
#   ('MA', 'Nov-2015'): '59104',
#   ('MA', 'Nov-2016'): '57362',
#   ('MA', 'Nov-2017'): '59559',
#   ('MA', 'Oct-2015'): '59151',
#   ('MA', 'Oct-2016'): '57073',
#   ('MA', 'Oct-2017'): '59624',
#   ('MA', 'Sep-2015'): '58924',
#   ('MA', 'Sep-2016'): '57129',
#   ('MA', 'Sep-2017'): '59535',
#   ('MD', 'Apr-2015'): '46928',
#   ('MD', 'Apr-2016'): '46898',
#   ('MD', 'Apr-2017'): '49576',
#   ('MD', 'Apr-2018'): '49855',
#   ('MD', 'Aug-2015'): '47457',
#   ('MD', 'Aug-2016'): '47548',
#   ('MD', 'Aug-2017'): '49549',
#   ('MD', 'Aug-2018'): '50035',
#   ('MD', 'Dec-2015'): '47162',
#   ('MD', 'Dec-2016'): '48668',
#   ('MD', 'Dec-2017'): '49670',
#   ('MD', 'Feb-2015'): '46765',
#   ('MD', 'Feb-2016'): '46686',
#   ('MD', 'Feb-2017'): '49189',
#   ('MD', 'Feb-2018'): '49967',
#   ('MD', 'Jan-2015'): '46592',
#   ('MD', 'Jan-2016'): '46615',
#   ('MD', 'Jan-2017'): '49031',
#   ('MD', 'Jan-2018'): '49961',
#   ('MD', 'Jul-2015'): '47386',
#   ('MD', 'Jul-2016'): '47315',
#   ('MD', 'Jul-2017'): '49530',
#   ('MD', 'Jul-2018'): '50066',
#   ('MD', 'Jun-2015'): '47301',
#   ('MD', 'Jun-2016'): '47120',
#   ('MD', 'Jun-2017'): '49654',
#   ('MD', 'Jun-2018'): '49863',
#   ('MD', 'Mar-2015'): '46818',
#   ('MD', 'Mar-2016'): '46689',
#   ('MD', 'Mar-2017'): '49489',
#   ('MD', 'Mar-2018'): '49930',
#   ('MD', 'May-2015'): '47095',
#   ('MD', 'May-2016'): '47054',
#   ('MD', 'May-2017'): '49556',
#   ('MD', 'May-2018'): '49828',
#   ('MD', 'Nov-2015'): '47583',
#   ('MD', 'Nov-2016'): '48351',
#   ('MD', 'Nov-2017'): '49539',
#   ('MD', 'Oct-2015'): '47630',
#   ('MD', 'Oct-2016'): '48045',
#   ('MD', 'Oct-2017'): '49527',
#   ('MD', 'Sep-2015'): '47485',
#   ('MD', 'Sep-2016'): '47868',
#   ('MD', 'Sep-2017'): '49583',
#   ('ME', 'Apr-2015'): '13993',
#   ('ME', 'Apr-2016'): '13868',
#   ('ME', 'Apr-2017'): '14445',
#   ('ME', 'Apr-2018'): '14507',
#   ('ME', 'Aug-2015'): '14179',
#   ('ME', 'Aug-2016'): '14005',
#   ('ME', 'Aug-2017'): '14391',
#   ('ME', 'Aug-2018'): '14474',
#   ('ME', 'Dec-2015'): '14324',
#   ('ME', 'Dec-2016'): '14069',
#   ('ME', 'Dec-2017'): '14513',
#   ('ME', 'Feb-2015'): '13845',
#   ('ME', 'Feb-2016'): '13952',
#   ('ME', 'Feb-2017'): '14224',
#   ('ME', 'Feb-2018'): '14640',
#   ('ME', 'Jan-2015'): '13627',
#   ('ME', 'Jan-2016'): '14129',
#   ('ME', 'Jan-2017'): '14136',
#   ('ME', 'Jan-2018'): '14604',
#   ('ME', 'Jul-2015'): '14052',
#   ('ME', 'Jul-2016'): '14044',
#   ('ME', 'Jul-2017'): '14325',
#   ('ME', 'Jul-2018'): '14491',
#   ('ME', 'Jun-2015'): '14016',
#   ('ME', 'Jun-2016'): '14059',
#   ('ME', 'Jun-2017'): '14362',
#   ('ME', 'Jun-2018'): '14443',
#   ('ME', 'Mar-2015'): '13901',
#   ('ME', 'Mar-2016'): '13897',
#   ('ME', 'Mar-2017'): '14326',
#   ('ME', 'Mar-2018'): '14551',
#   ('ME', 'May-2015'): '14023',
#   ('ME', 'May-2016'): '13964',
#   ('ME', 'May-2017'): '14342',
#   ('ME', 'May-2018'): '14474',
#   ('ME', 'Nov-2015'): '14367',
#   ('ME', 'Nov-2016'): '13983',
#   ('ME', 'Nov-2017'): '14491',
#   ('ME', 'Oct-2015'): '14368',
#   ('ME', 'Oct-2016'): '13923',
#   ('ME', 'Oct-2017'): '14467',
#   ('ME', 'Sep-2015'): '14296',
#   ('ME', 'Sep-2016'): '13937',
#   ('ME', 'Sep-2017'): '14479',
#   ('MI', 'Apr-2015'): '94589',
#   ('MI', 'Apr-2016'): '93368',
#   ('MI', 'Apr-2017'): '96144',
#   ('MI', 'Apr-2018'): '97058',
#   ('MI', 'Aug-2015'): '95190',
#   ('MI', 'Aug-2016'): '93445',
#   ('MI', 'Aug-2017'): '96265',
#   ('MI', 'Aug-2018'): '97427',
#   ('MI', 'Dec-2015'): '93920',
#   ('MI', 'Dec-2016'): '94840',
#   ('MI', 'Dec-2017'): '96266',
#   ('MI', 'Feb-2015'): '93559',
#   ('MI', 'Feb-2016'): '93407',
#   ('MI', 'Feb-2017'): '95549',
#   ('MI', 'Feb-2018'): '97115',
#   ('MI', 'Jan-2015'): '93274',
#   ('MI', 'Jan-2016'): '93137',
#   ('MI', 'Jan-2017'): '95468',
#   ('MI', 'Jan-2018'): '96771',
#   ('MI', 'Jul-2015'): '95051',
#   ('MI', 'Jul-2016'): '93394',
#   ('MI', 'Jul-2017'): '96246',
#   ('MI', 'Jul-2018'): '97298',
#   ('MI', 'Jun-2015'): '94937',
#   ('MI', 'Jun-2016'): '93472',
#   ('MI', 'Jun-2017'): '96216',
#   ('MI', 'Jun-2018'): '97114',
#   ('MI', 'Mar-2015'): '94086',
#   ('MI', 'Mar-2016'): '93268',
#   ('MI', 'Mar-2017'): '96017',
#   ('MI', 'Mar-2018'): '96963',
#   ('MI', 'May-2015'): '94659',
#   ...},
#  'footnote': {('AK',
#    'Apr-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Apr-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Apr-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Apr-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Aug-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Aug-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Aug-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Aug-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Dec-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Dec-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Dec-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Feb-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Feb-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Feb-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Feb-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Jan-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Jan-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Jan-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Jan-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Jul-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Jul-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Jul-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Jul-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Jun-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Jun-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Jun-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Jun-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Mar-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Mar-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Mar-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'Mar-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'May-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'May-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'May-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK', 'May-2018'): 'Underreported due to incomplete data.',
#   ('AK',
#    'Nov-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Nov-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Nov-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Oct-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Oct-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Oct-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Sep-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Sep-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AK',
#    'Sep-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Apr-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Apr-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Apr-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Apr-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Aug-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Aug-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Aug-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Aug-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Dec-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Dec-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Dec-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Feb-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Feb-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Feb-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Feb-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Jan-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Jan-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Jan-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Jan-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Jul-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Jul-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Jul-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Jul-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Jun-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Jun-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Jun-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Jun-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Mar-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Mar-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Mar-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'Mar-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'May-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'May-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'May-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL', 'May-2018'): 'Underreported due to incomplete data.',
#   ('AL',
#    'Nov-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Nov-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Nov-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Oct-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Oct-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Oct-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Sep-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Sep-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AL',
#    'Sep-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Apr-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Apr-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Apr-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Apr-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Aug-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Aug-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Aug-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Aug-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Dec-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Dec-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Dec-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Feb-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Feb-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Feb-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Feb-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Jan-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Jan-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Jan-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Jan-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Jul-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Jul-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Jul-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Jul-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Jun-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Jun-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Jun-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Jun-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Mar-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Mar-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Mar-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'Mar-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'May-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'May-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'May-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR', 'May-2018'): 'Underreported due to incomplete data.',
#   ('AR',
#    'Nov-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Nov-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Nov-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Oct-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Oct-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Oct-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Sep-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Sep-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AR',
#    'Sep-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Apr-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Apr-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Apr-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Apr-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Aug-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Aug-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Aug-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Aug-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Dec-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Dec-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Dec-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Feb-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Feb-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Feb-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Feb-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Jan-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Jan-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Jan-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Jan-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Jul-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Jul-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Jul-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Jul-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Jun-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Jun-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Jun-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Jun-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Mar-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Mar-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Mar-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'Mar-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'May-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'May-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'May-2017'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ', 'May-2018'): 'Underreported due to incomplete data.',
#   ('AZ',
#    'Nov-2015'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
#    'Nov-2016'): 'Numbers may differ from published reports using final data. See Technical Notes.',
#   ('AZ',
# ...
#   ('GA', 'Mar-2015'): '2015',
#   ('GA', 'Mar-2016'): '2016',
#   ('GA', 'Mar-2017'): '2017',
#   ('GA', 'Mar-2018'): '2018',
#   ('GA', 'May-2015'): '2015',
#   ('GA', 'May-2016'): '2016',
#   ('GA', 'May-2017'): '2017',
#   ('GA', 'May-2018'): '2018',
#   ('GA', 'Nov-2015'): '2015',
#   ('GA', 'Nov-2016'): '2016',
#   ('GA', 'Nov-2017'): '2017',
#   ('GA', 'Oct-2015'): '2015',
#   ('GA', 'Oct-2016'): '2016',
#   ('GA', 'Oct-2017'): '2017',
#   ('GA', 'Sep-2015'): '2015',
#   ('GA', 'Sep-2016'): '2016',
#   ('GA', 'Sep-2017'): '2017',
#   ('HI', 'Apr-2015'): '2015',
#   ('HI', 'Apr-2016'): '2016',
#   ('HI', 'Apr-2017'): '2017',
#   ('HI', 'Apr-2018'): '2018',
#   ('HI', 'Aug-2015'): '2015',
#   ('HI', 'Aug-2016'): '2016',
#   ('HI', 'Aug-2017'): '2017',
#   ('HI', 'Aug-2018'): '2018',
#   ('HI', 'Dec-2015'): '2015',
#   ('HI', 'Dec-2016'): '2016',
#   ('HI', 'Dec-2017'): '2017',
#   ('HI', 'Feb-2015'): '2015',
#   ('HI', 'Feb-2016'): '2016',
#   ('HI', 'Feb-2017'): '2017',
#   ('HI', 'Feb-2018'): '2018',
#   ('HI', 'Jan-2015'): '2015',
#   ('HI', 'Jan-2016'): '2016',
#   ('HI', 'Jan-2017'): '2017',
#   ('HI', 'Jan-2018'): '2018',
#   ('HI', 'Jul-2015'): '2015',
#   ('HI', 'Jul-2016'): '2016',
#   ('HI', 'Jul-2017'): '2017',
#   ('HI', 'Jul-2018'): '2018',
#   ('HI', 'Jun-2015'): '2015',
#   ('HI', 'Jun-2016'): '2016',
#   ('HI', 'Jun-2017'): '2017',
#   ('HI', 'Jun-2018'): '2018',
#   ('HI', 'Mar-2015'): '2015',
#   ('HI', 'Mar-2016'): '2016',
#   ('HI', 'Mar-2017'): '2017',
#   ('HI', 'Mar-2018'): '2018',
#   ('HI', 'May-2015'): '2015',
#   ('HI', 'May-2016'): '2016',
#   ('HI', 'May-2017'): '2017',
#   ('HI', 'May-2018'): '2018',
#   ('HI', 'Nov-2015'): '2015',
#   ('HI', 'Nov-2016'): '2016',
#   ('HI', 'Nov-2017'): '2017',
#   ('HI', 'Oct-2015'): '2015',
#   ('HI', 'Oct-2016'): '2016',
#   ('HI', 'Oct-2017'): '2017',
#   ('HI', 'Sep-2015'): '2015',
#   ('HI', 'Sep-2016'): '2016',
#   ('HI', 'Sep-2017'): '2017',
#   ('IA', 'Apr-2015'): '2015',
#   ('IA', 'Apr-2016'): '2016',
#   ('IA', 'Apr-2017'): '2017',
#   ('IA', 'Apr-2018'): '2018',
#   ('IA', 'Aug-2015'): '2015',
#   ('IA', 'Aug-2016'): '2016',
#   ('IA', 'Aug-2017'): '2017',
#   ('IA', 'Aug-2018'): '2018',
#   ('IA', 'Dec-2015'): '2015',
#   ('IA', 'Dec-2016'): '2016',
#   ('IA', 'Dec-2017'): '2017',
#   ('IA', 'Feb-2015'): '2015',
#   ('IA', 'Feb-2016'): '2016',
#   ('IA', 'Feb-2017'): '2017',
#   ('IA', 'Feb-2018'): '2018',
#   ('IA', 'Jan-2015'): '2015',
#   ('IA', 'Jan-2016'): '2016',
#   ('IA', 'Jan-2017'): '2017',
#   ('IA', 'Jan-2018'): '2018',
#   ('IA', 'Jul-2015'): '2015',
#   ('IA', 'Jul-2016'): '2016',
#   ('IA', 'Jul-2017'): '2017',
#   ('IA', 'Jul-2018'): '2018',
#   ('IA', 'Jun-2015'): '2015',
#   ('IA', 'Jun-2016'): '2016',
#   ('IA', 'Jun-2017'): '2017',
#   ('IA', 'Jun-2018'): '2018',
#   ('IA', 'Mar-2015'): '2015',
#   ('IA', 'Mar-2016'): '2016',
#   ('IA', 'Mar-2017'): '2017',
#   ('IA', 'Mar-2018'): '2018',
#   ('IA', 'May-2015'): '2015',
#   ('IA', 'May-2016'): '2016',
#   ('IA', 'May-2017'): '2017',
#   ('IA', 'May-2018'): '2018',
#   ('IA', 'Nov-2015'): '2015',
#   ('IA', 'Nov-2016'): '2016',
#   ('IA', 'Nov-2017'): '2017',
#   ('IA', 'Oct-2015'): '2015',
#   ('IA', 'Oct-2016'): '2016',
#   ('IA', 'Oct-2017'): '2017',
#   ('IA', 'Sep-2015'): '2015',
#   ('IA', 'Sep-2016'): '2016',
#   ('IA', 'Sep-2017'): '2017',
#   ('ID', 'Apr-2015'): '2015',
#   ('ID', 'Apr-2016'): '2016',
#   ('ID', 'Apr-2017'): '2017',
#   ('ID', 'Apr-2018'): '2018',
#   ('ID', 'Aug-2015'): '2015',
#   ('ID', 'Aug-2016'): '2016',
#   ('ID', 'Aug-2017'): '2017',
#   ('ID', 'Aug-2018'): '2018',
#   ('ID', 'Dec-2015'): '2015',
#   ('ID', 'Dec-2016'): '2016',
#   ('ID', 'Dec-2017'): '2017',
#   ('ID', 'Feb-2015'): '2015',
#   ('ID', 'Feb-2016'): '2016',
#   ('ID', 'Feb-2017'): '2017',
#   ('ID', 'Feb-2018'): '2018',
#   ('ID', 'Jan-2015'): '2015',
#   ('ID', 'Jan-2016'): '2016',
#   ('ID', 'Jan-2017'): '2017',
#   ('ID', 'Jan-2018'): '2018',
#   ('ID', 'Jul-2015'): '2015',
#   ('ID', 'Jul-2016'): '2016',
#   ('ID', 'Jul-2017'): '2017',
#   ('ID', 'Jul-2018'): '2018',
#   ('ID', 'Jun-2015'): '2015',
#   ('ID', 'Jun-2016'): '2016',
#   ('ID', 'Jun-2017'): '2017',
#   ('ID', 'Jun-2018'): '2018',
#   ('ID', 'Mar-2015'): '2015',
#   ('ID', 'Mar-2016'): '2016',
#   ('ID', 'Mar-2017'): '2017',
#   ('ID', 'Mar-2018'): '2018',
#   ('ID', 'May-2015'): '2015',
#   ('ID', 'May-2016'): '2016',
#   ('ID', 'May-2017'): '2017',
#   ('ID', 'May-2018'): '2018',
#   ('ID', 'Nov-2015'): '2015',
#   ('ID', 'Nov-2016'): '2016',
#   ('ID', 'Nov-2017'): '2017',
#   ('ID', 'Oct-2015'): '2015',
#   ('ID', 'Oct-2016'): '2016',
#   ('ID', 'Oct-2017'): '2017',
#   ('ID', 'Sep-2015'): '2015',
#   ('ID', 'Sep-2016'): '2016',
#   ('ID', 'Sep-2017'): '2017',
#   ('IL', 'Apr-2015'): '2015',
#   ('IL', 'Apr-2016'): '2016',
#   ('IL', 'Apr-2017'): '2017',
#   ('IL', 'Apr-2018'): '2018',
#   ('IL', 'Aug-2015'): '2015',
#   ('IL', 'Aug-2016'): '2016',
#   ('IL', 'Aug-2017'): '2017',
#   ('IL', 'Aug-2018'): '2018',
#   ('IL', 'Dec-2015'): '2015',
#   ('IL', 'Dec-2016'): '2016',
#   ('IL', 'Dec-2017'): '2017',
#   ('IL', 'Feb-2015'): '2015',
#   ('IL', 'Feb-2016'): '2016',
#   ('IL', 'Feb-2017'): '2017',
#   ('IL', 'Feb-2018'): '2018',
#   ('IL', 'Jan-2015'): '2015',
#   ('IL', 'Jan-2016'): '2016',
#   ('IL', 'Jan-2017'): '2017',
#   ('IL', 'Jan-2018'): '2018',
#   ('IL', 'Jul-2015'): '2015',
#   ('IL', 'Jul-2016'): '2016',
#   ('IL', 'Jul-2017'): '2017',
#   ('IL', 'Jul-2018'): '2018',
#   ('IL', 'Jun-2015'): '2015',
#   ('IL', 'Jun-2016'): '2016',
#   ('IL', 'Jun-2017'): '2017',
#   ('IL', 'Jun-2018'): '2018',
#   ('IL', 'Mar-2015'): '2015',
#   ('IL', 'Mar-2016'): '2016',
#   ('IL', 'Mar-2017'): '2017',
#   ('IL', 'Mar-2018'): '2018',
#   ('IL', 'May-2015'): '2015',
#   ('IL', 'May-2016'): '2016',
#   ('IL', 'May-2017'): '2017',
#   ('IL', 'May-2018'): '2018',
#   ('IL', 'Nov-2015'): '2015',
#   ('IL', 'Nov-2016'): '2016',
#   ('IL', 'Nov-2017'): '2017',
#   ('IL', 'Oct-2015'): '2015',
#   ('IL', 'Oct-2016'): '2016',
#   ('IL', 'Oct-2017'): '2017',
#   ('IL', 'Sep-2015'): '2015',
#   ('IL', 'Sep-2016'): '2016',
#   ('IL', 'Sep-2017'): '2017',
#   ('IN', 'Apr-2015'): '2015',
#   ('IN', 'Apr-2016'): '2016',
#   ('IN', 'Apr-2017'): '2017',
#   ('IN', 'Apr-2018'): '2018',
#   ('IN', 'Aug-2015'): '2015',
#   ('IN', 'Aug-2016'): '2016',
#   ('IN', 'Aug-2017'): '2017',
#   ('IN', 'Aug-2018'): '2018',
#   ('IN', 'Dec-2015'): '2015',
#   ('IN', 'Dec-2016'): '2016',
#   ('IN', 'Dec-2017'): '2017',
#   ('IN', 'Feb-2015'): '2015',
#   ('IN', 'Feb-2016'): '2016',
#   ('IN', 'Feb-2017'): '2017',
#   ('IN', 'Feb-2018'): '2018',
#   ('IN', 'Jan-2015'): '2015',
#   ('IN', 'Jan-2016'): '2016',
#   ('IN', 'Jan-2017'): '2017',
#   ('IN', 'Jan-2018'): '2018',
#   ('IN', 'Jul-2015'): '2015',
#   ('IN', 'Jul-2016'): '2016',
#   ('IN', 'Jul-2017'): '2017',
#   ('IN', 'Jul-2018'): '2018',
#   ('IN', 'Jun-2015'): '2015',
#   ('IN', 'Jun-2016'): '2016',
#   ('IN', 'Jun-2017'): '2017',
#   ('IN', 'Jun-2018'): '2018',
#   ('IN', 'Mar-2015'): '2015',
#   ('IN', 'Mar-2016'): '2016',
#   ('IN', 'Mar-2017'): '2017',
#   ('IN', 'Mar-2018'): '2018',
#   ('IN', 'May-2015'): '2015',
#   ('IN', 'May-2016'): '2016',
#   ('IN', 'May-2017'): '2017',
#   ('IN', 'May-2018'): '2018',
#   ('IN', 'Nov-2015'): '2015',
#   ('IN', 'Nov-2016'): '2016',
#   ('IN', 'Nov-2017'): '2017',
#   ('IN', 'Oct-2015'): '2015',
#   ('IN', 'Oct-2016'): '2016',
#   ('IN', 'Oct-2017'): '2017',
#   ('IN', 'Sep-2015'): '2015',
#   ('IN', 'Sep-2016'): '2016',
#   ('IN', 'Sep-2017'): '2017',
#   ('KS', 'Apr-2015'): '2015',
#   ('KS', 'Apr-2016'): '2016',
#   ('KS', 'Apr-2017'): '2017',
#   ('KS', 'Apr-2018'): '2018',
#   ('KS', 'Aug-2015'): '2015',
#   ('KS', 'Aug-2016'): '2016',
#   ('KS', 'Aug-2017'): '2017',
#   ('KS', 'Aug-2018'): '2018',
#   ('KS', 'Dec-2015'): '2015',
#   ('KS', 'Dec-2016'): '2016',
#   ('KS', 'Dec-2017'): '2017',
#   ('KS', 'Feb-2015'): '2015',
#   ('KS', 'Feb-2016'): '2016',
#   ('KS', 'Feb-2017'): '2017',
#   ('KS', 'Feb-2018'): '2018',
#   ('KS', 'Jan-2015'): '2015',
#   ('KS', 'Jan-2016'): '2016',
#   ('KS', 'Jan-2017'): '2017',
#   ('KS', 'Jan-2018'): '2018',
#   ('KS', 'Jul-2015'): '2015',
#   ('KS', 'Jul-2016'): '2016',
#   ('KS', 'Jul-2017'): '2017',
#   ('KS', 'Jul-2018'): '2018',
#   ('KS', 'Jun-2015'): '2015',
#   ('KS', 'Jun-2016'): '2016',
#   ('KS', 'Jun-2017'): '2017',
#   ('KS', 'Jun-2018'): '2018',
#   ('KS', 'Mar-2015'): '2015',
#   ('KS', 'Mar-2016'): '2016',
#   ('KS', 'Mar-2017'): '2017',
#   ('KS', 'Mar-2018'): '2018',
#   ('KS', 'May-2015'): '2015',
#   ('KS', 'May-2016'): '2016',
#   ('KS', 'May-2017'): '2017',
#   ('KS', 'May-2018'): '2018',
#   ('KS', 'Nov-2015'): '2015',
#   ('KS', 'Nov-2016'): '2016',
#   ('KS', 'Nov-2017'): '2017',
#   ('KS', 'Oct-2015'): '2015',
#   ('KS', 'Oct-2016'): '2016',
#   ('KS', 'Oct-2017'): '2017',
#   ('KS', 'Sep-2015'): '2015',
#   ('KS', 'Sep-2016'): '2016',
#   ('KS', 'Sep-2017'): '2017',
#   ('KY', 'Apr-2015'): '2015',
#   ('KY', 'Apr-2016'): '2016',
#   ('KY', 'Apr-2017'): '2017',
#   ('KY', 'Apr-2018'): '2018',
#   ('KY', 'Aug-2015'): '2015',
#   ('KY', 'Aug-2016'): '2016',
#   ('KY', 'Aug-2017'): '2017',
#   ('KY', 'Aug-2018'): '2018',
#   ('KY', 'Dec-2015'): '2015',
#   ('KY', 'Dec-2016'): '2016',
#   ('KY', 'Dec-2017'): '2017',
#   ('KY', 'Feb-2015'): '2015',
#   ('KY', 'Feb-2016'): '2016',
#   ('KY', 'Feb-2017'): '2017',
#   ('KY', 'Feb-2018'): '2018',
#   ('KY', 'Jan-2015'): '2015',
#   ('KY', 'Jan-2016'): '2016',
#   ('KY', 'Jan-2017'): '2017',
#   ('KY', 'Jan-2018'): '2018',
#   ('KY', 'Jul-2015'): '2015',
#   ('KY', 'Jul-2016'): '2016',
#   ('KY', 'Jul-2017'): '2017',
#   ('KY', 'Jul-2018'): '2018',
#   ('KY', 'Jun-2015'): '2015',
#   ('KY', 'Jun-2016'): '2016',
#   ('KY', 'Jun-2017'): '2017',
#   ('KY', 'Jun-2018'): '2018',
#   ('KY', 'Mar-2015'): '2015',
#   ('KY', 'Mar-2016'): '2016',
#   ('KY', 'Mar-2017'): '2017',
#   ('KY', 'Mar-2018'): '2018',
#   ('KY', 'May-2015'): '2015',
#   ('KY', 'May-2016'): '2016',
#   ('KY', 'May-2017'): '2017',
#   ('KY', 'May-2018'): '2018',
#   ('KY', 'Nov-2015'): '2015',
#   ('KY', 'Nov-2016'): '2016',
#   ('KY', 'Nov-2017'): '2017',
#   ('KY', 'Oct-2015'): '2015',
#   ('KY', 'Oct-2016'): '2016',
#   ('KY', 'Oct-2017'): '2017',
#   ('KY', 'Sep-2015'): '2015',
#   ('KY', 'Sep-2016'): '2016',
#   ('KY', 'Sep-2017'): '2017',
#   ('LA', 'Apr-2015'): '2015',
#   ('LA', 'Apr-2016'): '2016',
#   ('LA', 'Apr-2017'): '2017',
#   ('LA', 'Apr-2018'): '2018',
#   ('LA', 'Aug-2015'): '2015',
#   ('LA', 'Aug-2016'): '2016',
#   ('LA', 'Aug-2017'): '2017',
#   ('LA', 'Aug-2018'): '2018',
#   ('LA', 'Dec-2015'): '2015',
#   ('LA', 'Dec-2016'): '2016',
#   ('LA', 'Dec-2017'): '2017',
#   ('LA', 'Feb-2015'): '2015',
#   ('LA', 'Feb-2016'): '2016',
#   ('LA', 'Feb-2017'): '2017',
#   ('LA', 'Feb-2018'): '2018',
#   ('LA', 'Jan-2015'): '2015',
#   ('LA', 'Jan-2016'): '2016',
#   ('LA', 'Jan-2017'): '2017',
#   ('LA', 'Jan-2018'): '2018',
#   ('LA', 'Jul-2015'): '2015',
#   ('LA', 'Jul-2016'): '2016',
#   ('LA', 'Jul-2017'): '2017',
#   ('LA', 'Jul-2018'): '2018',
#   ('LA', 'Jun-2015'): '2015',
#   ('LA', 'Jun-2016'): '2016',
#   ('LA', 'Jun-2017'): '2017',
#   ('LA', 'Jun-2018'): '2018',
#   ('LA', 'Mar-2015'): '2015',
#   ('LA', 'Mar-2016'): '2016',
#   ('LA', 'Mar-2017'): '2017',
#   ('LA', 'Mar-2018'): '2018',
#   ('LA', 'May-2015'): '2015',
#   ('LA', 'May-2016'): '2016',
#   ('LA', 'May-2017'): '2017',
#   ('LA', 'May-2018'): '2018',
#   ('LA', 'Nov-2015'): '2015',
#   ('LA', 'Nov-2016'): '2016',
#   ('LA', 'Nov-2017'): '2017',
#   ('LA', 'Oct-2015'): '2015',
#   ('LA', 'Oct-2016'): '2016',
#   ('LA', 'Oct-2017'): '2017',
#   ('LA', 'Sep-2015'): '2015',
#   ('LA', 'Sep-2016'): '2016',
#   ('LA', 'Sep-2017'): '2017',
#   ('MA', 'Apr-2015'): '2015',
#   ('MA', 'Apr-2016'): '2016',
#   ('MA', 'Apr-2017'): '2017',
#   ('MA', 'Apr-2018'): '2018',
#   ('MA', 'Aug-2015'): '2015',
#   ('MA', 'Aug-2016'): '2016',
#   ('MA', 'Aug-2017'): '2017',
#   ('MA', 'Aug-2018'): '2018',
#   ('MA', 'Dec-2015'): '2015',
#   ('MA', 'Dec-2016'): '2016',
#   ('MA', 'Dec-2017'): '2017',
#   ('MA', 'Feb-2015'): '2015',
#   ('MA', 'Feb-2016'): '2016',
#   ('MA', 'Feb-2017'): '2017',
#   ('MA', 'Feb-2018'): '2018',
#   ('MA', 'Jan-2015'): '2015',
#   ('MA', 'Jan-2016'): '2016',
#   ('MA', 'Jan-2017'): '2017',
#   ('MA', 'Jan-2018'): '2018',
#   ('MA', 'Jul-2015'): '2015',
#   ('MA', 'Jul-2016'): '2016',
#   ('MA', 'Jul-2017'): '2017',
#   ('MA', 'Jul-2018'): '2018',
#   ('MA', 'Jun-2015'): '2015',
#   ('MA', 'Jun-2016'): '2016',
#   ('MA', 'Jun-2017'): '2017',
#   ('MA', 'Jun-2018'): '2018',
#   ('MA', 'Mar-2015'): '2015',
#   ('MA', 'Mar-2016'): '2016',
#   ('MA', 'Mar-2017'): '2017',
#   ('MA', 'Mar-2018'): '2018',
#   ('MA', 'May-2015'): '2015',
#   ('MA', 'May-2016'): '2016',
#   ('MA', 'May-2017'): '2017',
#   ('MA', 'May-2018'): '2018',
#   ('MA', 'Nov-2015'): '2015',
#   ('MA', 'Nov-2016'): '2016',
#   ('MA', 'Nov-2017'): '2017',
#   ('MA', 'Oct-2015'): '2015',
#   ('MA', 'Oct-2016'): '2016',
#   ('MA', 'Oct-2017'): '2017',
#   ('MA', 'Sep-2015'): '2015',
#   ('MA', 'Sep-2016'): '2016',
#   ('MA', 'Sep-2017'): '2017',
#   ('MD', 'Apr-2015'): '2015',
#   ('MD', 'Apr-2016'): '2016',
#   ('MD', 'Apr-2017'): '2017',
#   ('MD', 'Apr-2018'): '2018',
#   ('MD', 'Aug-2015'): '2015',
#   ('MD', 'Aug-2016'): '2016',
#   ('MD', 'Aug-2017'): '2017',
#   ('MD', 'Aug-2018'): '2018',
#   ('MD', 'Dec-2015'): '2015',
#   ('MD', 'Dec-2016'): '2016',
#   ('MD', 'Dec-2017'): '2017',
#   ('MD', 'Feb-2015'): '2015',
#   ('MD', 'Feb-2016'): '2016',
#   ('MD', 'Feb-2017'): '2017',
#   ('MD', 'Feb-2018'): '2018',
#   ('MD', 'Jan-2015'): '2015',
#   ('MD', 'Jan-2016'): '2016',
#   ('MD', 'Jan-2017'): '2017',
#   ('MD', 'Jan-2018'): '2018',
#   ('MD', 'Jul-2015'): '2015',
#   ('MD', 'Jul-2016'): '2016',
#   ('MD', 'Jul-2017'): '2017',
#   ('MD', 'Jul-2018'): '2018',
#   ('MD', 'Jun-2015'): '2015',
#   ('MD', 'Jun-2016'): '2016',
#   ('MD', 'Jun-2017'): '2017',
#   ('MD', 'Jun-2018'): '2018',
#   ('MD', 'Mar-2015'): '2015',
#   ('MD', 'Mar-2016'): '2016',
#   ('MD', 'Mar-2017'): '2017',
#   ('MD', 'Mar-2018'): '2018',
#   ('MD', 'May-2015'): '2015',
#   ('MD', 'May-2016'): '2016',
#   ('MD', 'May-2017'): '2017',
#   ('MD', 'May-2018'): '2018',
#   ('MD', 'Nov-2015'): '2015',
#   ('MD', 'Nov-2016'): '2016',
#   ('MD', 'Nov-2017'): '2017',
#   ('MD', 'Oct-2015'): '2015',
#   ('MD', 'Oct-2016'): '2016',
#   ('MD', 'Oct-2017'): '2017',
#   ('MD', 'Sep-2015'): '2015',
#   ('MD', 'Sep-2016'): '2016',
#   ('MD', 'Sep-2017'): '2017',
#   ('ME', 'Apr-2015'): '2015',
#   ('ME', 'Apr-2016'): '2016',
#   ('ME', 'Apr-2017'): '2017',
#   ('ME', 'Apr-2018'): '2018',
#   ('ME', 'Aug-2015'): '2015',
#   ('ME', 'Aug-2016'): '2016',
#   ('ME', 'Aug-2017'): '2017',
#   ('ME', 'Aug-2018'): '2018',
#   ('ME', 'Dec-2015'): '2015',
#   ('ME', 'Dec-2016'): '2016',
#   ('ME', 'Dec-2017'): '2017',
#   ('ME', 'Feb-2015'): '2015',
#   ('ME', 'Feb-2016'): '2016',
#   ('ME', 'Feb-2017'): '2017',
#   ('ME', 'Feb-2018'): '2018',
#   ('ME', 'Jan-2015'): '2015',
#   ('ME', 'Jan-2016'): '2016',
#   ('ME', 'Jan-2017'): '2017',
#   ('ME', 'Jan-2018'): '2018',
#   ('ME', 'Jul-2015'): '2015',
#   ('ME', 'Jul-2016'): '2016',
#   ('ME', 'Jul-2017'): '2017',
#   ('ME', 'Jul-2018'): '2018',
#   ('ME', 'Jun-2015'): '2015',
#   ('ME', 'Jun-2016'): '2016',
#   ('ME', 'Jun-2017'): '2017',
#   ('ME', 'Jun-2018'): '2018',
#   ('ME', 'Mar-2015'): '2015',
#   ('ME', 'Mar-2016'): '2016',
#   ('ME', 'Mar-2017'): '2017',
#   ('ME', 'Mar-2018'): '2018',
#   ('ME', 'May-2015'): '2015',
#   ('ME', 'May-2016'): '2016',
#   ('ME', 'May-2017'): '2017',
#   ('ME', 'May-2018'): '2018',
#   ('ME', 'Nov-2015'): '2015',
#   ('ME', 'Nov-2016'): '2016',
#   ('ME', 'Nov-2017'): '2017',
#   ('ME', 'Oct-2015'): '2015',
#   ('ME', 'Oct-2016'): '2016',
#   ('ME', 'Oct-2017'): '2017',
#   ('ME', 'Sep-2015'): '2015',
#   ('ME', 'Sep-2016'): '2016',
#   ('ME', 'Sep-2017'): '2017',
#   ('MI', 'Apr-2015'): '2015',
#   ('MI', 'Apr-2016'): '2016',
#   ('MI', 'Apr-2017'): '2017',
#   ('MI', 'Apr-2018'): '2018',
#   ('MI', 'Aug-2015'): '2015',
#   ('MI', 'Aug-2016'): '2016',
#   ('MI', 'Aug-2017'): '2017',
#   ('MI', 'Aug-2018'): '2018',
#   ('MI', 'Dec-2015'): '2015',
#   ('MI', 'Dec-2016'): '2016',
#   ('MI', 'Dec-2017'): '2017',
#   ('MI', 'Feb-2015'): '2015',
#   ('MI', 'Feb-2016'): '2016',
#   ('MI', 'Feb-2017'): '2017',
#   ('MI', 'Feb-2018'): '2018',
#   ('MI', 'Jan-2015'): '2015',
#   ('MI', 'Jan-2016'): '2016',
#   ('MI', 'Jan-2017'): '2017',
#   ('MI', 'Jan-2018'): '2018',
#   ('MI', 'Jul-2015'): '2015',
#   ('MI', 'Jul-2016'): '2016',
#   ('MI', 'Jul-2017'): '2017',
#   ('MI', 'Jul-2018'): '2018',
#   ('MI', 'Jun-2015'): '2015',
#   ('MI', 'Jun-2016'): '2016',
#   ('MI', 'Jun-2017'): '2017',
#   ('MI', 'Jun-2018'): '2018',
#   ('MI', 'Mar-2015'): '2015',
#   ('MI', 'Mar-2016'): '2016',
#   ('MI', 'Mar-2017'): '2017',
#   ('MI', 'Mar-2018'): '2018',
#   ('MI', 'May-2015'): '2015',
#   ...}}

# %%
#push dataframe contents to mysql

import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

dbuser = 'root'
#read in password from config.py file
dbpassword = password
dbhost = 'localhost'
dbport = '3306'

#database name is Project2 (need to create this locally)
dbname= 'project2'

engine = create_engine(f"mysql://{dbuser}:{dbpassword}@{dbhost}:{dbport}/{dbname}")

# state_cons_df
drug_df.to_sql('drug', engine, index=True, if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1170, "BLOB/TEXT column 'state' used in key specification without a key length")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-24-99875fd54067> in <module>()
#      17
#      18 # state_cons_df
# ---> 19 drug_df.to_sql('drug', engine, index=True, if_exists="replace")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2530         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2531                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2532                    dtype=dtype, method=method)
#    2533
#    2534     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1171                          if_exists=if_exists, index_label=index_label,
#    1172                          schema=schema, dtype=dtype)
# -> 1173         table.create()
#    1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     576             elif self.if_exists == 'replace':
#     577                 self.pd_sql.drop_table(self.name, self.schema)
# --> 578                 self._execute_create()
#     579             elif self.if_exists == 'append':
#     580                 pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_create(self)
#     567         # Inserting table into database, add to MetaData object
#     568         self.table = self.table.tometadata(self.pd_sql.meta)
# --> 569         self.table.create()
#     570
#     571     def create(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/schema.py in create(self, bind, checkfirst)
#     777         bind._run_visitor(ddl.SchemaGenerator,
#     778                           self,
# --> 779                           checkfirst=checkfirst)
#     780
#     781     def drop(self, bind=None, checkfirst=False):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _run_visitor(self, visitorcallable, element, connection, **kwargs)
#    1938                      connection=None, **kwargs):
#    1939         with self._optional_conn_ctx_manager(connection) as conn:
# -> 1940             conn._run_visitor(visitorcallable, element, **kwargs)
#    1941
#    1942     class _trans_ctx(object):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _run_visitor(self, visitorcallable, element, **kwargs)
#    1547     def _run_visitor(self, visitorcallable, element, **kwargs):
#    1548         visitorcallable(self.dialect, self,
# -> 1549                         **kwargs).traverse_single(element)
#    1550
#    1551
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     119             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     120             if meth:
# --> 121                 return meth(obj, **kw)
#     122
#     123     def iterate(self, obj):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     794         if hasattr(table, 'indexes'):
#     795             for index in table.indexes:
# --> 796                 self.traverse_single(index)
#     797
#     798         if self.dialect.supports_comments and not self.dialect.inline_comments:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     119             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     120             if meth:
# --> 121                 return meth(obj, **kw)
#     122
#     123     def iterate(self, obj):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in visit_index(self, index)
#     821
#     822     def visit_index(self, index):
# --> 823         self.connection.execute(CreateIndex(index))
#     824
#     825
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in _execute_on_connection(self, connection, multiparams, params)
#      66
#      67     def _execute_on_connection(self, connection, multiparams, params):
# ---> 68         return connection._execute_ddl(self, multiparams, params)
#      69
#      70     def execute(self, bind=None, target=None):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_ddl(self, ddl, multiparams, params)
#    1007             compiled,
#    1008             None,
# -> 1009             compiled
#    1010         )
#    1011         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1170, "BLOB/TEXT column 'state' used in key specification without a key length") [SQL: 'CREATE INDEX ix_drug_state ON drug (state)'] (Background on this error at: http://sqlalche.me/e/2j85)

# %%
state = "NY"
indicators = drug_df['indicator'].unique()

drug_df[(drug_df['indicator']==indicators[1]) & (drug_df['state']==state)].sort_values(by='month-year')
# Out:
#       data_value                                           footnote  \
# 4616       96525  Numbers may differ from published reports usin...
# 4590       97079  Numbers may differ from published reports usin...
# 3226       97885  Numbers may differ from published reports usin...
# 4875       98250  Numbers may differ from published reports usin...
# 7054       98620  Numbers may differ from published reports usin...
# 1239       98695  Numbers may differ from published reports usin...
# 1599       98964  Numbers may differ from published reports usin...
# 1694       99184  Numbers may differ from published reports usin...
# 5886       99349  Numbers may differ from published reports usin...
# 4997       99526  Numbers may differ from published reports usin...
# 2371       99173  Numbers may differ from published reports usin...
# 1281       98476  Numbers may differ from published reports usin...
# 5359       97781  Numbers may differ from published reports usin...
# 2098       97445  Numbers may differ from published reports usin...
# 7178       97131  Numbers may differ from published reports usin...
# 6416       97051  Numbers may differ from published reports usin...
# 4706       96971  Numbers may differ from published reports usin...
# 7294       97038  Numbers may differ from published reports usin...
# 3012       97055  Numbers may differ from published reports usin...
# 3818       97223  Numbers may differ from published reports usin...
# 3043       97410  Numbers may differ from published reports usin...
# 8278       97512  Numbers may differ from published reports usin...
# 3284       98048  Numbers may differ from published reports usin...
# 872        98766  Numbers may differ from published reports usin...
# 824        99099  Numbers may differ from published reports usin...
# 640        99210  Numbers may differ from published reports usin...
# 6814       99308  Numbers may differ from published reports usin...
# 3085       99275  Numbers may differ from published reports usin...
# 7550       99358  Numbers may differ from published reports usin...
# 2364       99706  Numbers may differ from published reports usin...
# 8280       99677  Numbers may differ from published reports usin...
# 8320       99672  Numbers may differ from published reports usin...
# 715        99699  Numbers may differ from published reports usin...
# 6589       99369  Numbers may differ from published reports usin...
# 1304       99428  Numbers may differ from published reports usin...
# 1330       99799  Numbers may differ from published reports usin...
# 12921     100553              Underreported due to incomplete data.
# 9242      100551              Underreported due to incomplete data.
# 11739     100757              Underreported due to incomplete data.
# 13810     100769              Underreported due to incomplete data.
# 11432     100725              Underreported due to incomplete data.
# 4679      100744              Underreported due to incomplete data.
# 9414      100804              Underreported due to incomplete data.
# 12495     100828              Underreported due to incomplete data.
# 13113     100605              Underreported due to incomplete data.
# 9028      100566              Underreported due to incomplete data.
# 11070     100482              Underreported due to incomplete data.
# 13529     100529              Underreported due to incomplete data.
# 9308      100707              Underreported due to incomplete data.
# 187       100754              Underreported due to incomplete data.
# 12432     100859              Underreported due to incomplete data.
#
#               indicator      month percent_complete  \
# 4616   Number of Deaths    January              100
# 4590   Number of Deaths   February              100
# 3226   Number of Deaths      March              100
# 4875   Number of Deaths      April              100
# 7054   Number of Deaths        May              100
# 1239   Number of Deaths       June              100
# 1599   Number of Deaths       July              100
# 1694   Number of Deaths     August              100
# 5886   Number of Deaths  September              100
# 4997   Number of Deaths    October              100
# 2371   Number of Deaths   November              100
# 1281   Number of Deaths   December              100
# 5359   Number of Deaths    January              100
# 2098   Number of Deaths   February              100
# 7178   Number of Deaths      March              100
# 6416   Number of Deaths      April              100
# 4706   Number of Deaths        May              100
# 7294   Number of Deaths       June              100
# 3012   Number of Deaths       July              100
# 3818   Number of Deaths     August              100
# 3043   Number of Deaths  September              100
# 8278   Number of Deaths    October              100
# 3284   Number of Deaths   November              100
# 872    Number of Deaths   December              100
# 824    Number of Deaths    January              100
# 640    Number of Deaths   February              100
# 6814   Number of Deaths      March              100
# 3085   Number of Deaths      April              100
# 7550   Number of Deaths        May              100
# 2364   Number of Deaths       June              100
# 8280   Number of Deaths       July              100
# 8320   Number of Deaths     August              100
# 715    Number of Deaths  September              100
# 6589   Number of Deaths    October              100
# 1304   Number of Deaths   November              100
# 1330   Number of Deaths   December              100
# 12921  Number of Deaths    January              100
# 9242   Number of Deaths    January              100
# 11739  Number of Deaths   February              100
# 13810  Number of Deaths   February              100
# 11432  Number of Deaths      March              100
# 4679   Number of Deaths      March              100
# 9414   Number of Deaths      April              100
# 12495  Number of Deaths      April              100
# 13113  Number of Deaths        May              100
# 9028   Number of Deaths        May              100
# 11070  Number of Deaths       June              100
# 13529  Number of Deaths       June              100
# 9308   Number of Deaths       July              100
# 187    Number of Deaths       July              100
# 12432  Number of Deaths     August              100
#
#       percent_pending_investigation predicted_value state state_name  year  \
# 4616              0.278684278684279             NaN    NY         NY  2015
# 4590               0.29460542444813             NaN    NY         NY  2015
# 3226              0.306482096337539             NaN    NY         NY  2015
# 4875              0.307379134860051             NaN    NY         NY  2015
# 7054              0.313323869397688             NaN    NY         NY  2015
# 1239              0.309032879071888             NaN    NY         NY  2015
# 1599              0.322339436562791             NaN    NY         NY  2015
# 1694              0.337756089691886             NaN    NY         NY  2015
# 5886              0.353299982888605             NaN    NY         NY  2015
# 4997              0.370757390028736             NaN    NY         NY  2015
# 2371              0.395268873584544             NaN    NY         NY  2015
# 1281              0.405174864941712             NaN    NY         NY  2015
# 5359              0.408054734559884             NaN    NY         NY  2016
# 2098              0.401251988301093             NaN    NY         NY  2016
# 7178              0.409755896675624             NaN    NY         NY  2016
# 6416              0.423488681208849             NaN    NY         NY  2016
# 4706              0.437244124532077             NaN    NY         NY  2016
# 7294               0.46476638018096             NaN    NY         NY  2016
# 3012              0.483231157591057             NaN    NY         NY  2016
# 3818              0.493710336031597             NaN    NY         NY  2016
# 3043              0.514320911610718             NaN    NY         NY  2016
# 8278              0.531216670768726             NaN    NY         NY  2016
# 3284              0.540551566579634             NaN    NY         NY  2016
# 872               0.585221634975599             NaN    NY         NY  2016
# 824               0.575182393364212             NaN    NY         NY  2017
# 640               0.574538856970064             NaN    NY         NY  2017
# 6814              0.566923107906714             NaN    NY         NY  2017
# 3085              0.557038529337698             NaN    NY         NY  2017
# 7550              0.548521508081886             NaN    NY         NY  2017
# 2364              0.539586383968868             NaN    NY         NY  2017
# 8280              0.525698004554712             NaN    NY         NY  2017
# 8320              0.511678304839875             NaN    NY         NY  2017
# 715               0.511539734601149             NaN    NY         NY  2017
# 6589               0.51122583501897             NaN    NY         NY  2017
# 1304              0.504887959126202             NaN    NY         NY  2017
# 1330              0.498000981973767             NaN    NY         NY  2017
# 12921             0.510178711724165             NaN    NY         NY  2018
# 9242              0.515161460353452             NaN    NY         NY  2018
# 11739             0.527010530285737             NaN    NY         NY  2018
# 13810             0.521985928212049             NaN    NY         NY  2018
# 11432             0.551998014395632             NaN    NY         NY  2018
# 4679              0.541967759866593             NaN    NY         NY  2018
# 9414              0.578350065473592             NaN    NY         NY  2018
# 12495             0.561352005395327             NaN    NY         NY  2018
# 13113               0.5695541971075             NaN    NY         NY  2018
# 9028              0.597617485034704             NaN    NY         NY  2018
# 11070             0.629963575565773             NaN    NY         NY  2018
# 13529             0.588884799411115             NaN    NY         NY  2018
# 9308              0.678205090013604             NaN    NY         NY  2018
# 187               0.616352700637195             NaN    NY         NY  2018
# 12432             0.659336301172925             NaN    NY         NY  2018
#
#       month-year
# 4616  2015-01-01
# 4590  2015-02-01
# 3226  2015-03-01
# 4875  2015-04-01
# 7054  2015-05-01
# 1239  2015-06-01
# 1599  2015-07-01
# 1694  2015-08-01
# 5886  2015-09-01
# 4997  2015-10-01
# 2371  2015-11-01
# 1281  2015-12-01
# 5359  2016-01-01
# 2098  2016-02-01
# 7178  2016-03-01
# 6416  2016-04-01
# 4706  2016-05-01
# 7294  2016-06-01
# 3012  2016-07-01
# 3818  2016-08-01
# 3043  2016-09-01
# 8278  2016-10-01
# 3284  2016-11-01
# 872   2016-12-01
# 824   2017-01-01
# 640   2017-02-01
# 6814  2017-03-01
# 3085  2017-04-01
# 7550  2017-05-01
# 2364  2017-06-01
# 8280  2017-07-01
# 8320  2017-08-01
# 715   2017-09-01
# 6589  2017-10-01
# 1304  2017-11-01
# 1330  2017-12-01
# 12921 2018-01-01
# 9242  2018-01-01
# 11739 2018-02-01
# 13810 2018-02-01
# 11432 2018-03-01
# 4679  2018-03-01
# 9414  2018-04-01
# 12495 2018-04-01
# 13113 2018-05-01
# 9028  2018-05-01
# 11070 2018-06-01
# 13529 2018-06-01
# 9308  2018-07-01
# 187   2018-07-01
# 12432 2018-08-01

# %%
# Out:
#                   data_value  \
# state year
# VT    2015                24
# NC    2015             89864
# NV    2015               271
# NM    2016               236
# US    2017   85.557639810282
# TN    2016             69856
# VT    2015                79
# NH    2016                 6
# MT    2017             10237
# WA    2015               292
# ME    2015                41
# VT    2018                32
# DE    2016              8740
# IN    2015              1162
# YC    2015  98.1481481481482
# MO    2016             60964
# GA    2017             82813
# ME    2018                29
#       2015                39
# NV    2017                51
# ME    2016             13897
# KY    2015              1101
# NV    2016                50
# OR    2015                60
# WA    2015               355
# MD    2015               166
# NV    2017               294
# YC    2016  98.1762917933131
# US    2015              8216
# CT    2016             30641
# ...                      ...
# RI    2017               107
# MN    2018               667
# VA    2018              1152
#       2017              1003
# NY    2018            100769
# YC    2017               429
# VT    2015                22
# UT    2017               377
# OK    2016               383
# NC    2018               435
# IN    2018              1701
# US    2018             16936
# NH    2017                67
# YC    2018               863
# VA    2016               407
# SC    2018               773
# NV    2018               295
# MD    2015               672
# NM    2016               236
# UT    2016               420
# NC    2018               679
# US    2015             15406
# MD    2018              2038
# WI    2018              1140
# NV    2018               304
# VT    2016                32
# NM    2017               195
# VT    2015                31
# SC    2016               534
# YC    2018              1195
#
#                                                      footnote  \
# state year
# VT    2015  Numbers may differ from published reports usin...
# NC    2015  Numbers may differ from published reports usin...
# NV    2015  Numbers may differ from published reports usin...
# NM    2016  Numbers may differ from published reports usin...
# US    2017  Numbers may differ from published reports usin...
# TN    2016  Numbers may differ from published reports usin...
# VT    2015  Numbers may differ from published reports usin...
# NH    2016  Numbers may differ from published reports usin...
# MT    2017  Numbers may differ from published reports usin...
# WA    2015  Numbers may differ from published reports usin...
# ME    2015  Numbers may differ from published reports usin...
# VT    2018              Underreported due to incomplete data.
# DE    2016  Numbers may differ from published reports usin...
# IN    2015  Numbers may differ from published reports usin...
# YC    2015  Numbers may differ from published reports usin...
# MO    2016  Numbers may differ from published reports usin...
# GA    2017  Numbers may differ from published reports usin...
# ME    2018              Underreported due to incomplete data.
#       2015  Numbers may differ from published reports usin...
# NV    2017  Numbers may differ from published reports usin...
# ME    2016  Numbers may differ from published reports usin...
# KY    2015  Numbers may differ from published reports usin...
# NV    2016  Numbers may differ from published reports usin...
# OR    2015  Numbers may differ from published reports usin...
# WA    2015  Numbers may differ from published reports usin...
# MD    2015  Numbers may differ from published reports usin...
# NV    2017  Numbers may differ from published reports usin...
# YC    2016  Numbers may differ from published reports usin...
# US    2015  Numbers may differ from published reports usin...
# CT    2016  Numbers may differ from published reports usin...
# ...                                                       ...
# RI    2017  Numbers may differ from published reports usin...
# MN    2018              Underreported due to incomplete data.
# VA    2018              Underreported due to incomplete data.
#       2017  Numbers may differ from published reports usin...
# NY    2018              Underreported due to incomplete data.
# YC    2017  Numbers may differ from published reports usin...
# VT    2015  Numbers may differ from published reports usin...
# UT    2017  Numbers may differ from published reports usin...
# OK    2016  Numbers may differ from published reports usin...
# NC    2018              Underreported due to incomplete data.
# IN    2018              Underreported due to incomplete data.
# US    2018              Underreported due to incomplete data.
# NH    2017  Numbers may differ from published reports usin...
# YC    2018              Underreported due to incomplete data.
# VA    2016  Numbers may differ from published reports usin...
# SC    2018              Underreported due to incomplete data.
# NV    2018              Underreported due to incomplete data.
# MD    2015  Numbers may differ from published reports usin...
# NM    2016  Numbers may differ from published reports usin...
# UT    2016  Numbers may differ from published reports usin...
# NC    2018              Underreported due to incomplete data.
# US    2015  Numbers may differ from published reports usin...
# MD    2018              Underreported due to incomplete data.
# WI    2018              Underreported due to incomplete data.
# NV    2018              Underreported due to incomplete data.
# VT    2016  Numbers may differ from published reports usin...
# NM    2017  Numbers may differ from published reports usin...
# VT    2015  Numbers may differ from published reports usin...
# SC    2016  Numbers may differ from published reports usin...
# YC    2018              Underreported due to incomplete data.
#
#                                                     indicator      month  \
# state year
# VT    2015           Natural & semi-synthetic opioids (T40.2)  September
# NC    2015                                   Number of Deaths     August
# NV    2015           Natural & semi-synthetic opioids (T40.2)   December
# NM    2016  Natural, semi-synthetic, & synthetic opioids, ...   November
# US    2017                       Percent with drugs specified    January
# TN    2016                                   Number of Deaths      March
# VT    2015                        Opioids (T40.0-T40.4,T40.6)   November
# NH    2016      Psychostimulants with abuse potential (T43.6)      March
# MT    2017                                   Number of Deaths        May
# WA    2015                                     Heroin (T40.1)      April
# ME    2015                                  Methadone (T40.3)      April
# VT    2018  Natural & semi-synthetic opioids, incl. methad...      March
# DE    2016                                   Number of Deaths  September
# IN    2015                     Number of Drug Overdose Deaths    January
# YC    2015                       Percent with drugs specified        May
# MO    2016                                   Number of Deaths        May
# GA    2017                                   Number of Deaths        May
# ME    2018                                  Methadone (T40.3)    January
#       2015                                  Methadone (T40.3)       June
# NV    2017                                  Methadone (T40.3)       June
# ME    2016                                   Number of Deaths      March
# KY    2015                     Number of Drug Overdose Deaths    January
# NV    2016         Synthetic opioids, excl. methadone (T40.4)    October
# OR    2015                                  Methadone (T40.3)       June
# WA    2015  Natural & semi-synthetic opioids, incl. methad...  September
# MD    2015                                  Methadone (T40.3)     August
# NV    2017      Psychostimulants with abuse potential (T43.6)       July
# YC    2016                       Percent with drugs specified    January
# US    2015         Synthetic opioids, excl. methadone (T40.4)     August
# CT    2016                                   Number of Deaths   December
# ...                                                       ...        ...
# RI    2017  Natural & semi-synthetic opioids, incl. methad...       June
# MN    2018                     Number of Drug Overdose Deaths     August
# VA    2018                        Opioids (T40.0-T40.4,T40.6)       July
#       2017  Natural, semi-synthetic, & synthetic opioids, ...   November
# NY    2018                                   Number of Deaths   February
# YC    2017  Natural & semi-synthetic opioids, incl. methad...   November
# VT    2015  Natural & semi-synthetic opioids, incl. methad...    January
# UT    2017  Natural, semi-synthetic, & synthetic opioids, ...      April
# OK    2016  Natural, semi-synthetic, & synthetic opioids, ...   February
# NC    2018           Natural & semi-synthetic opioids (T40.2)       July
# IN    2018                     Number of Drug Overdose Deaths      April
# US    2018  Natural & semi-synthetic opioids, incl. methad...    January
# NH    2017  Natural & semi-synthetic opioids, incl. methad...       July
# YC    2018         Synthetic opioids, excl. methadone (T40.4)       June
# VA    2016  Natural & semi-synthetic opioids, incl. methad...   November
# SC    2018                        Opioids (T40.0-T40.4,T40.6)      April
# NV    2018  Natural & semi-synthetic opioids, incl. methad...    January
# MD    2015  Natural, semi-synthetic, & synthetic opioids, ...      March
# NM    2016  Natural, semi-synthetic, & synthetic opioids, ...        May
# UT    2016  Natural & semi-synthetic opioids, incl. methad...   February
# NC    2018                                    Cocaine (T40.5)       July
# US    2015  Natural & semi-synthetic opioids, incl. methad...    October
# MD    2018                        Opioids (T40.0-T40.4,T40.6)    January
# WI    2018                     Number of Drug Overdose Deaths       June
# NV    2018  Natural, semi-synthetic, & synthetic opioids, ...       July
# VT    2016  Natural & semi-synthetic opioids, incl. methad...       June
# NM    2017  Natural & semi-synthetic opioids, incl. methad...      April
# VT    2015  Natural & semi-synthetic opioids, incl. methad...     August
# SC    2016  Natural, semi-synthetic, & synthetic opioids, ...   December
# YC    2018                        Opioids (T40.0-T40.4,T40.6)   February
#
#            percent_complete percent_pending_investigation predicted_value  \
# state year
# VT    2015              100                             0              25
# NC    2015              100             0.364995993946408             NaN
# NV    2015              100            0.0042288662409608             273
# NM    2016              100            0.0339520144861929             238
# US    2017              100             0.164728689174528             NaN
# TN    2016              100             0.284871736142923             NaN
# VT    2015              100                             0              80
# NH    2016              100            0.0345811359903173               7
# MT    2017              100            0.0879163817524665             NaN
# WA    2015              100           0.00754517674576527             293
# ME    2015              100            0.0214392910741085              42
# VT    2018              100                             0              33
# DE    2016              100                             0             NaN
# IN    2015              100             0.033776176536816            1170
# YC    2015              100            0.0222102944714875             NaN
# MO    2016              100            0.0229643724165081             NaN
# GA    2017              100            0.0796976320142973             NaN
# ME    2018              100                             0              29
#       2015              100            0.0142694063926941              40
# NV    2017              100           0.00787835815016151              52
# ME    2016              100                             0             NaN
# KY    2015              100            0.0155863819554229            1106
# NV    2016              100                             0              51
# OR    2015              100            0.0226269940038466              61
# WA    2015              100           0.00552201443086438             357
# MD    2015              100            0.0105358535094928             167
# NV    2017              100           0.00785453402976868             298
# YC    2016              100            0.0391615694465165             NaN
# US    2015              100             0.148719883671925            8455
# CT    2016              100            0.0261088084592539             NaN
# ...                     ...                           ...             ...
# RI    2017              100            0.0677441207780896             109
# MN    2018              100                             0             673
# VA    2018              100            0.0912475900334084            1174
#       2017              100            0.0415479582146249            1012
# NY    2018              100             0.521985928212049             NaN
# YC    2017              100            0.0387161003668811             434
# VT    2015              100                             0              23
# UT    2017              100             0.807369276618803             433
# OK    2016              100            0.0184521299029945             385
# NC    2018              100             0.610767686373963             480
# IN    2018              100            0.0740382581366535            1722
# US    2018              100             0.150940769196691           17234
# NH    2017              100            0.0492610837438424              68
# YC    2018              100             0.150914578711953             894
# VA    2016              100             0.013802834181952             410
# SC    2018              100             0.178394048125849             795
# NV    2018              100            0.0891611102496511             298
# MD    2015              100            0.0085437224998932             675
# NM    2016              100            0.0911317423249986             240
# UT    2016              100             0.384615384615385             446
# NC    2018              100             0.610767686373963             735
# US    2015              100              0.15293214597802           15806
# MD    2018              100            0.0360281019194972            2040
# WI    2018              100             0.228811493088768            1181
# NV    2018              100             0.147475453098925             314
# VT    2016              100                             0              33
# NM    2017              100            0.0674574175051998             198
# VT    2015              100                             0              32
# SC    2016              100            0.0381979076035057             539
# YC    2018              100            0.0655510843241865            1207
#
#            state_name month-year
# state year
# VT    2015         VT 2015-09-01
# NC    2015         NC 2015-08-01
# NV    2015         NV 2015-12-01
# NM    2016         NM 2016-11-01
# US    2017         US 2017-01-01
# TN    2016         TN 2016-03-01
# VT    2015         VT 2015-11-01
# NH    2016         NH 2016-03-01
# MT    2017         MT 2017-05-01
# WA    2015         WA 2015-04-01
# ME    2015         ME 2015-04-01
# VT    2018         VT 2018-03-01
# DE    2016         DE 2016-09-01
# IN    2015         IN 2015-01-01
# YC    2015         YC 2015-05-01
# MO    2016         MO 2016-05-01
# GA    2017         GA 2017-05-01
# ME    2018         ME 2018-01-01
#       2015         ME 2015-06-01
# NV    2017         NV 2017-06-01
# ME    2016         ME 2016-03-01
# KY    2015         KY 2015-01-01
# NV    2016         NV 2016-10-01
# OR    2015         OR 2015-06-01
# WA    2015         WA 2015-09-01
# MD    2015         MD 2015-08-01
# NV    2017         NV 2017-07-01
# YC    2016         YC 2016-01-01
# US    2015         US 2015-08-01
# CT    2016         CT 2016-12-01
# ...               ...        ...
# RI    2017         RI 2017-06-01
# MN    2018         MN 2018-08-01
# VA    2018         VA 2018-07-01
#       2017         VA 2017-11-01
# NY    2018         NY 2018-02-01
# YC    2017         YC 2017-11-01
# VT    2015         VT 2015-01-01
# UT    2017         UT 2017-04-01
# OK    2016         OK 2016-02-01
# NC    2018         NC 2018-07-01
# IN    2018         IN 2018-04-01
# US    2018         US 2018-01-01
# NH    2017         NH 2017-07-01
# YC    2018         YC 2018-06-01
# VA    2016         VA 2016-11-01
# SC    2018         SC 2018-04-01
# NV    2018         NV 2018-01-01
# MD    2015         MD 2015-03-01
# NM    2016         NM 2016-05-01
# UT    2016         UT 2016-02-01
# NC    2018         NC 2018-07-01
# US    2015         US 2015-10-01
# MD    2018         MD 2018-01-01
# WI    2018         WI 2018-06-01
# NV    2018         NV 2018-07-01
# VT    2016         VT 2016-06-01
# NM    2017         NM 2017-04-01
# VT    2015         VT 2015-08-01
# SC    2016         SC 2016-12-01
# YC    2018         YC 2018-02-01
#
# [13836 rows x 9 columns]

# %%
indicators
# Out:
# array(['Natural & semi-synthetic opioids (T40.2)', 'Number of Deaths',
#        'Natural, semi-synthetic, & synthetic opioids, incl. methadone (T40.2-T40.4)',
#        'Percent with drugs specified', 'Opioids (T40.0-T40.4,T40.6)',
#        'Psychostimulants with abuse potential (T43.6)', 'Heroin (T40.1)',
#        'Methadone (T40.3)',
#        'Natural & semi-synthetic opioids, incl. methadone (T40.2, T40.3)',
#        'Number of Drug Overdose Deaths',
#        'Synthetic opioids, excl. methadone (T40.4)', 'Cocaine (T40.5)'],
#       dtype=object)
